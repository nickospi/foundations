# %% [markdown]
# # Mine Safety
#
# We're interested in [US mine safety](https://arlweb.msha.gov/drs/drshome.htm), thank goodness we can search for these things.

# %% [markdown]
# ## Setup: Import what you'll need to search and scrape and Selenium

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
driver=webdriver.Chrome()

# %% [markdown]
# ## Starting from `https://arlweb.msha.gov/drs/drshome.htm`, search for every operator with 'dirt' in their name, including abandoned mines.
#
# > - *Tip: If you can't make an element work using name, class or ID, try to use the XPath*

# %%
driver.get("https://arlweb.msha.gov/drs/drshome.htm")

# %%
oper_name=driver.find_element_by_name("OperSearch")

# %%
driver.execute_script("arguments[0].scrollIntoView(true)", oper_name)

# %%
oper_name.send_keys("dirt")

# %%
box=driver.find_element_by_name("Abandoned") 
#clicking box in order to "uncheck it" and include abandoned mines
box.click()
search=driver.find_element_by_xpath ('//*[@id="content"]/form[1]/table/tbody/tr[7]/td[3]/input[1]')
search.click()

# %% [markdown]
# ## Scrape the results page, saving it as `dirt-operators.csv`
#
# > - *Tip: Think about what each row in your dataset will be, and start by looping through that*
# > - *Tip: Printing is cool and good! Print everything! Move it into a dictionary later.*
# > - *Tip: If you don't want a row, think about what's in the row that makes it different. You can use an `if` statement or list slicing to skip the ones you aren't interested in.*
# > - *Tip: Make sure your dictionary and your loop variable have DIFFERENT NAMES*
# > - *Tip: After you've made your dictionary (and printed it, of course), you'll want to add it to your list of rows*
# > - *Tip: Be sure to import pandas to convert it to a dataframe*
# > - *Tip: Make sure you don't include the index when saving your dataframe*

# %% [markdown]
# ### Hopefully you know that each `tr` is supposed to be a row of your data. What is the index of the first row element that is actually a result?
#
# > - *Tip: `.text` will help you here.*
# > - *Tip: You aren't interesting in annotations or anything, just mines and where they are from*
# > - *Tip: Using `print("-----")` will help you keep track of different rows*
# > - *Tip: If you have a list called `animals`, `animals[2:]` will skip the first two and start with the third. You can use this to skip ahead to the 'good' data if you want*

# %%
indx_row=driver.find_elements_by_tag_name('tr')[6:7]
for row in indx_row:
    print(row.text)
# Out:
# ID State Operator Mine Name Type CM* Status Commodity More Info

# %% [markdown]
# ### Loop through each operator result, printing its name
#
# > - *Tip: If you have a list called `animals`, `animals[2:]` will skip the first two and start with the third.*
# > - *Tip: You can use list slicing or an `if` statement to skip the non-data row(s). List slicing is probably easier, even if you aren't comfortable with it.*
# > - *Tip: or honestly you can use `try` and `except` if you know how it works.*
# > - *Tip: Once you have the "right" rows of data, you're going to be looking for a certain tag inside*
# > - *Tip: Sometimes you can't say "give me this class," and instead you have to say "give me all of the `div` elements, and then give me the third one."*

# %%
rows=driver.find_elements_by_tag_name('tr')[6:]
for row in rows:
    try:
        operator=row.find_elements_by_tag_name('td')
        print(operator[2].text)
    except:
        pass
# Out:
# Newberg Rock & Dirt
# Allied Dirt Moving Company
# AM Dirtworks & Aggregate Sales
# Atlas-Dirty Devil Mining
# Atlas-Dirty Devil Mining
# Babe's Dirt Work
# Bar-Lin Dirt Company
# Barber'S Dirt Pit
# Bender Sand & Dirt
# BERT'S DIRT
# Big D Dirt Service Inc
# Big Red Dirt Farm LLC
# Big River Dirt Pit
# Bob Harris Dirt Contracting
# Bohannon Sand & Dirt
# Bratcher'S Sand & Dirt
# Brewer Dirt Works
# Buck'S Dirt Pit
# C & G Dirt Hauling
# C N C Dirt Movers, Inc.
# Cambridge Dirt Sand and Gravel LLC
# Central Iowa Dirt & Demo LLC
# Crowes Trucking & Dirt Pit Services
# D & H Dirt
# Diez Dirt & Sand Hauling Inc
# Dirt Cheap
# Dirt Company
# Dirt Company
# Dirt Company
# Dirt Con
# Dirt Diggers Inc
# Dirt Doctor Inc
# Dirt Inc
# Dirt Pit
# Dirt Work Specialists LLC
# Dirt Works
# Dirtco Inc
# Dirtman Trucking
# DIRTWORKS, INC.
# Dirtworks, Inc.
# Dirty Coal
# Dorchester Dirt Company Inc
# Douglas Dirt Sand & Gravel Company
# Ell Dirt Works LLC.
# Floyd Smith Dirt Pit
# Gary Kelm Dirt Service
# Gerald Fenger/Rock & Dirt Const
# Gerald Illies Gravel & Dirt Company
# Guidry Sand & Dirt Pit Inc
# Harris Dirt Company Inc
# Hatchet Creek Rock & Dirt LLC
# Holley Dirt Company, Inc
# Iske Dirt Sand & Gravel
# J M Lynn Dirtwork
# Jake Diel Dirt & Paving Inc
# Jake Diel Dirt & Paving Inc
# Jake Diel Dirt & Paving Inc
# Jake Diel Dirt & Paving Inc
# Jake Diel Dirt & Paving Inc
# Jake Diel Dirt & Paving Inc
# Jake Diel Dirt & Paving Inc
# Jake Diel Dirt & Paving Inc
# Jarratt Dirt Work and Paving, Inc.
# JBS DIRT, INC.
# Jones Bros Dirt & Paving Contractors Inc
# Krueger Brothers Gravel & Dirt
# Krueger Dirt Werx, Inc.
# L I P Dirt & Trucking
# Lee'S Dirt Pit Inc
# Little-G-Dirt Pit
# Lone Star Dirt & Paving
# Loyd'S Dirt & Gravel
# M R Dirt
# M.C. Dirt LLC
# M.R. Dirt Inc.
# Maurice Dirt & Sand
# Mc Dirt Industries Inc
# Mike Duhon Dirt Pit
# Mike Duhon Dirt Pit
# Mike Duhon Dirt Pit
# Moss Dirt Company
# Moss Dirt Company
# Muckler Fill Dirt & Top Soil
# Nelson & Sons Dirt Haulers Inc
# Nelson'S Dirt Pit
# Nicholson Dirt Contracting
# Nitty Gritty Dirt LLC
# Northest Louisiana Dirt Contractors
# Orvil Carter Dirt Contractor Inc
# Orvil Carter Dirt Contractor Inc
# P B Dirt Movers Inc
# P B Dirt Movers Inc
# P B Dirt Movers Inc
# P B Dirt Movers Inc
# P B Dirt Movers Inc
# P B Dirt Movers Inc.
# P B Dirt Movers, Inc
# P B Dirt Movers, Inc.
# P.B. Dirtmovers
# PAPA'S DIRT WORKES
# Paydirt Exc Inc
# PB Dirt Movers
# PB Dirt Movers Inc.
# PB Dirt Movers, Inc
# Peveto Dirt Pit
# Phil-Dirt Industries, Inc
# Prescott Dirt, LLC
# R & R Dirtworks
# R D Blankenship Dirt Work LLC
# Reeves Dirt Pit Inc
# River Bottom Dirt
# Roe'S Dirt Pit
# Russell Trest-Dirt Contractor
# S J Stahr Dirt Movers Inc
# Sand & Dirt, Inc
# Sand and Dirt, Inc.
# Sierra Rock & Dirt, Inc.
# Simpson Dirtworx llc
# SIMPSON DIRTWORX LLC
# SIMPSON DIRTWORX LLC
# Slay'S Dirt Hauling
# Southside Dirt Company
# Spry's Dirt & Gravel, Inc.
# Stewart Dirt Pit
# Stewart Dirt Work, Inc.
# Sweat'S Dirt Hauling Inc
# Toler Roe Dirt Pit
# Tres Palacios Dirt, Sand & Gravel
# Vogt Dirt Service
# Watson Dirt Sand & Gravel Pit Inc
# Y B Dirt & Loam
# Yarbrough Dirt Pit Inc

# %% [markdown]
# ### Loop through each operator result, printing its ID
#
# There should be ONE code per row, and NO empty rows between them.

# %%
for row in rows:
    try:
        id=row.find_elements_by_tag_name('td')
        print(id[0].text)
    except:
        pass
# Out:
# 3503598
# 0502030
# 4801789
# 4201449
# 4201450
# 1002257
# 1601167
# 4103265
# 1401575
# 1700776
# 1601251
# 0301963
# 1601082
# 3401751
# 1600916
# 3401211
# 0301267
# 1600956
# 2200033
# 0504953
# 3401929
# 1302445
# 1601106
# 3400915
# 1600983
# 4503200
# 3401266
# 3401468
# 5001797
# 4608254
# 1510279
# 2103723
# 0100776
# 4104016
# 2103914
# 4104757
# 0301729
# 0404851
# 2200734
# 5002028
# 1513393
# 3800602
# 3101630
# 3200860
# 3401762
# 2103517
# 2402626
# 2103181
# 1601124
# 1601150
# 4703427
# 0801306
# 2501216
# 3200965
# 2901371
# 2901544
# 2901709
# 4102355
# 4102420
# 4102869
# 4102951
# 4102958
# 4104876
# 3003502
# 4103258
# 3901432
# 2103556
# 1601250
# 1600908
# 1600953
# 4104185
# 2901536
# 3609624
# 3800709
# 3609931
# 1601257
# 0801275
# 1601379
# 1601380
# 1601381
# 1601134
# 1601165
# 3901042
# 1601194
# 4104054
# 4801674
# 2402474
# 1600920
# 4102955
# 4103107
# 1512530
# 1515619
# 1518318
# 4405366
# 4407196
# 1519685
# 1519799
# 4407379
# 4407003
# 2602570
# 2402503
# 4407296
# 1519273
# 4407270
# 4102682
# 0801259
# 0203332
# 0302015
# 2901986
# 1601127
# 4105017
# 1600986
# 4103324
# 4202013
# 0801417
# 0801371
# 2402115
# 4300748
# 4300768
# 4300776
# 0103209
# 1601159
# 2302283
# 4102586
# 4104475
# 3800617
# 1601234
# 4104648
# 2103518
# 1601292
# 4103429
# 4103264
# Total Number of Mines Found:  132

# %% [markdown]
# ## Saving the results
#
# ### Loop through each `tr` to create a list of dictionaries
#
# Each dictionary must contain
#
# - Operator ID
# - Operator name
# - Mine name
# - State
# - Mine type
# - Coal or metal
# - Status
# - Commodity
#
# Create a new dictionary for each row.
#
# > - *Tip: Start with an empty dictionary, then add the keys one at a time like we did during class*
# > - *Tip: You might want to save all of the cells in a variable, then use indexes to get the second, third, fourth, etc.*
# > - *Tip: I know you already skipped a bunch of rows already, but one of them still might be bad! Which one is it? How can you skip it? You might need to slice out some of the end of your list, too. Use `print` to help you debug, or just look at the page closely.*
# > - *Tip: Or, if you did the other homework already, `try` / `except` is also an option*

# %%
rows=driver.find_elements_by_tag_name('tr')[6:]
named_dirt=[]
for row in rows:
    try:    
        operators={}
        cell=row.find_elements_by_tag_name ('td')
        operators['ID']=cell[0].text
        operators['Name']=cell[2].text
        operators['Mine_name']=cell[3].text
        operators['State']=cell[1].text
        operators['Mine_type']=cell[4].text
        operators['Coal_or_Metal']=cell[5].text
        operators['Status']=cell[6].text
        operators['Commodity']=cell[7].text   
        named_dirt.append(operators)
    except:
        pass

# %% [markdown]
# ### Save that to a CSV named `dirt-operators.csv`

# %%
import pandas as pd
df=pd.DataFrame(named_dirt)

# %%
df.to_csv("mines.csv", index=False)

# %% [markdown]
# ### Open the CSV file and examine the first few.
#
# Make sure you didn't save that extra weird unnamed index column.

# %%
pd.read_csv('/Users/nickospi/Desktop/mines.csv')
# Out:
#     Coal_or_Metal                       Commodity       ID  \
# 0              M       Crushed, Broken Stone NEC   3503598
# 1              M    Construction Sand and Gravel    502030
# 2              M    Construction Sand and Gravel   4801789
# 3              C               Coal (Bituminous)   4201449
# 4              C               Coal (Bituminous)   4201450
# 5              M    Construction Sand and Gravel   1002257
# 6              M    Construction Sand and Gravel   1601167
# 7              M    Construction Sand and Gravel   4103265
# 8              M    Construction Sand and Gravel   1401575
# 9              M    Construction Sand and Gravel   1700776
# 10             M    Construction Sand and Gravel   1601251
# 11             M    Construction Sand and Gravel    301963
# 12             M    Construction Sand and Gravel   1601082
# 13             M    Construction Sand and Gravel   3401751
# 14             M    Construction Sand and Gravel   1600916
# 15             M    Construction Sand and Gravel   3401211
# 16             M    Construction Sand and Gravel    301267
# 17             M    Construction Sand and Gravel   1600956
# 18             M                Common Clays NEC   2200033
# 19             M    Construction Sand and Gravel    504953
# 20             M            Sand, Industrial NEC   3401929
# 21             M    Construction Sand and Gravel   1302445
# 22             M    Construction Sand and Gravel   1601106
# 23             M    Construction Sand and Gravel   3400915
# 24             M    Construction Sand and Gravel   1600983
# 25             M                Common Clays NEC   4503200
# 26             M    Construction Sand and Gravel   3401266
# 27             M    Construction Sand and Gravel   3401468
# 28             M    Construction Sand and Gravel   5001797
# 29             M   Crushed, Broken Limestone NEC   4608254
# ..            ...                             ...      ...
# 102            C               Coal (Bituminous)   1519273
# 103            C               Coal (Bituminous)   4407270
# 104            M    Construction Sand and Gravel   4102682
# 105            M    Construction Sand and Gravel    801259
# 106            M    Construction Sand and Gravel    203332
# 107            M   Crushed, Broken Limestone NEC    302015
# 108            M    Construction Sand and Gravel   2901986
# 109            M    Construction Sand and Gravel   1601127
# 110            M                    Sand, Common   4105017
# 111            M    Construction Sand and Gravel   1600986
# 112            M    Construction Sand and Gravel   4103324
# 113            M    Construction Sand and Gravel   4202013
# 114            M                    Sand, Common    801417
# 115            M                    Sand, Common    801371
# 116            M    Construction Sand and Gravel   2402115
# 117            M    Construction Sand and Gravel   4300748
# 118            M    Construction Sand and Gravel   4300768
# 119            M    Construction Sand and Gravel   4300776
# 120            M    Construction Sand and Gravel    103209
# 121            M    Construction Sand and Gravel   1601159
# 122            M    Construction Sand and Gravel   2302283
# 123            M    Construction Sand and Gravel   4102586
# 124            M       Crushed, Broken Stone NEC   4104475
# 125            M    Construction Sand and Gravel   3800617
# 126            M    Construction Sand and Gravel   1601234
# 127            M    Construction Sand and Gravel   4104648
# 128            M    Construction Sand and Gravel   2103518
# 129            M    Construction Sand and Gravel   1601292
# 130            M    Construction Sand and Gravel   4103429
# 131            M    Construction Sand and Gravel   4103264
#
#                              Mine_name Mine_type  \
# 0                  Newberg Rock & Dirt   Surface
# 1    Allied Dirt Moving Co Pit & Plant   Surface
# 2       AM Dirtworks & Aggregate Sales   Surface
# 3          Unit Train Loading Facility  Facility
# 4    Blackie Surface Mine & Prep Plant   Surface
# 5                       Hitt Pit, Inc.   Surface
# 6                     Bar-Lin Dirt Pit   Surface
# 7                    Barber'S Dirt Pit   Surface
# 8                   BENDER SAND & DIRT   Surface
# 9                          BERT'S DIRT   Surface
# 10                       Dorothy V Pit   Surface
# 11                   Big Red Dirt Farm   Surface
# 12                  Big River Dirt Pit   Surface
# 13                          Harris Pit   Surface
# 14                BOHANNON SAND & DIRT   Surface
# 15                         Eubanks Pit   Surface
# 16                          Brewer Pit   Surface
# 17                     Buck'S Dirt Pit   Surface
# 18                 Laurel Brick & Tile   Surface
# 19                       Foster Canyon   Surface
# 20                        Cambridge #1   Surface
# 21                           Woolstock   Surface
# 22                     Crowes Dirt Pit   Surface
# 23                          D & H Dirt   Surface
# 24                  Amite Acres Dredge   Surface
# 25                          Dirt Cheap   Surface
# 26                              Pit #1   Surface
# 27                           Hicks Pit   Surface
# 28                          Bush Pilot   Surface
# 29                     Hog Lick Quarry   Surface
# ..                                 ...       ...
# 102                      Blair Face Up   Surface
# 103                 Surface Mine No. 1   Surface
# 104                         Peveto Pit   Surface
# 105                             PIT #1   Surface
# 106                    Sandretto Drive   Surface
# 107                     Martins Quarry   Surface
# 108          R D BLANKENSHIP DIRT WORK   Surface
# 109       Reeves Dirt Pit Incorporated   Surface
# 110                  River Bottom Dirt   Surface
# 111                     Roe'S Dirt Pit   Surface
# 112                     Pine Ridge Pit   Surface
# 113             Stahr Portable Crusher   Surface
# 114                         Molino Pit   Surface
# 115                        CENTURY PIT   Surface
# 116             Sierra Rock & Dirt Inc   Surface
# 117            Simpson Sand and Gravel   Surface
# 118              Pettibone Jaw Crusher   Surface
# 119                      Chieftan 1400   Surface
# 120                           SLAY PIT   Surface
# 121                 Southside Dirt Pit   Surface
# 122                   Mike's Money Pit   Surface
# 123                        Stewart Pit   Surface
# 124  Stewart Dirt Work Inc - Hanna Pit   Surface
# 125               Highway 642 Dirt Pit   Surface
# 126                 Toler Roe Dirt Pit   Surface
# 127                   La Calichera Pit   Surface
# 128                            Crusher   Surface
# 129                      ADDISON LEASE   Surface
# 130                           Y B Mine   Surface
# 131              Yarbrough Dirt Pit #1   Surface
#
#                                       Name State         Status
# 0                    Newberg Rock & Dirt     OR         Active
# 1             Allied Dirt Moving Company     CO      Abandoned
# 2         AM Dirtworks & Aggregate Sales     ND      Abandoned
# 3               Atlas-Dirty Devil Mining     UT      Abandoned
# 4               Atlas-Dirty Devil Mining     UT      Abandoned
# 5                       Babe's Dirt Work     ID      Abandoned
# 6                   Bar-Lin Dirt Company     LA      Abandoned
# 7                      Barber'S Dirt Pit     TX      Abandoned
# 8                     Bender Sand & Dirt     KS   Intermittent
# 9                            BERT'S DIRT     ME      Abandoned
# 10                Big D Dirt Service Inc     LA      Abandoned
# 11                 Big Red Dirt Farm LLC     AR      Abandoned
# 12                    Big River Dirt Pit     LA      Abandoned
# 13           Bob Harris Dirt Contracting     OK      Abandoned
# 14                  Bohannon Sand & Dirt     LA      Abandoned
# 15                Bratcher'S Sand & Dirt     OK      Abandoned
# 16                     Brewer Dirt Works     AR      Abandoned
# 17                       Buck'S Dirt Pit     LA      Abandoned
# 18                    C & G Dirt Hauling     MS      Abandoned
# 19               C N C Dirt Movers, Inc.     NM      Abandoned
# 20    Cambridge Dirt Sand and Gravel LLC     OK      Abandoned
# 21          Central Iowa Dirt & Demo LLC     IA      Abandoned
# 22   Crowes Trucking & Dirt Pit Services     LA      Abandoned
# 23                            D & H Dirt     OK      Abandoned
# 24          Diez Dirt & Sand Hauling Inc     LA      Abandoned
# 25                            Dirt Cheap     WA      Abandoned
# 26                          Dirt Company     OK      Abandoned
# 27                          Dirt Company     OK      Abandoned
# 28                          Dirt Company     AK   Intermittent
# 29                              Dirt Con     WV      Abandoned
# ..                                     ...   ...            ...
# 102                  PB Dirt Movers Inc.     KY      Abandoned
# 103                  PB Dirt Movers, Inc     VA      Abandoned
# 104                      Peveto Dirt Pit     TX      Abandoned
# 105            Phil-Dirt Industries, Inc     FL      Abandoned
# 106                   Prescott Dirt, LLC     AZ   Intermittent
# 107                      R & R Dirtworks     AR      Abandoned
# 108        R D Blankenship Dirt Work LLC     NM         Active
# 109                  Reeves Dirt Pit Inc     LA      Abandoned
# 110                    River Bottom Dirt     TX      Abandoned
# 111                       Roe'S Dirt Pit     LA      Abandoned
# 112        Russell Trest-Dirt Contractor     TX      Abandoned
# 113            S J Stahr Dirt Movers Inc     UT      Abandoned
# 114                     Sand & Dirt, Inc     FL         Active
# 115                  Sand and Dirt, Inc.     FL      Abandoned
# 116             Sierra Rock & Dirt, Inc.     MT      Abandoned
# 117                 Simpson Dirtworx llc     VT      Abandoned
# 118                 SIMPSON DIRTWORX LLC     VT   Intermittent
# 119                 SIMPSON DIRTWORX LLC     VT   Intermittent
# 120                  Slay'S Dirt Hauling     AL      Abandoned
# 121               Southside Dirt Company     LA      Abandoned
# 122           Spry's Dirt & Gravel, Inc.     MO   Intermittent
# 123                     Stewart Dirt Pit     TX      Abandoned
# 124              Stewart Dirt Work, Inc.     TX      Abandoned
# 125             Sweat'S Dirt Hauling Inc     SC      Abandoned
# 126                   Toler Roe Dirt Pit     LA      Abandoned
# 127    Tres Palacios Dirt, Sand & Gravel     TX      Abandoned
# 128                    Vogt Dirt Service     MN   Intermittent
# 129    Watson Dirt Sand & Gravel Pit Inc     LA      Abandoned
# 130                      Y B Dirt & Loam     TX      Abandoned
# 131               Yarbrough Dirt Pit Inc     TX      Abandoned
#
# [132 rows x 8 columns]
