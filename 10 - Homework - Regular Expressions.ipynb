# %% [markdown]
# # Homework 10: Cleaning data with Regular Expressions
#
# Time to use regular expressions!
#
# # Hints and notes
#
# ### Opening files in subdirectories
#
# Notice that this notebook might be **homework/**, but!!! the csvs and text files might be in **homework/scraped/** or **/homework/scraped/minutes_pdfs** or **/homework/pdfs/**. To open a file in a subdirectory, instead of having the filename be `"file.csv"` you'll just use `"some/subfolder/file.csv"`
#
# ### Opening text files
#
# This will open up a file, read it in and show you the first 500 characters.
#
# ```python
# contents = open("your-filename.txt").read()
# contents[0:500]
# ```
#
# > You might need `open("your-filename.txt", encoding="utf8").read()`
#
# ### Using regex
#
# For some dumb reason you need to put `r` in front of the string you use when you're talking about regex. Just plain `"(\d\d\d)"` will usually work, but *sometimes* it won't and you'll need `r"(\d\d\d)`. It's best to just use the `r` all of the time, if you can remember!
#
# ### Using `.str.extract`
#
# When you use `.str.extract`, you're always going to **capture one thing** and save it to a new column. You need to wrap the things you're interested in with parenthesis `(` `)`.
#
# ```python
# df['phone_number'] = df['old_column'].str.extract(r"My phone number is (\d\d\d-\d\d\d-\d\d\d\d)")
# ```
#
# ### Setting pandas options
#
# Pandas has a lot of options, like how many columns or rows it will show you, or how many characters it will show in a column before it stops showing you anything. Here are a few useful ones:
#
# * `display.max_cols`: Number of columns to show at once
# * `display.max_rows`: Number of rows to show at once
# * `display.max_colwidth`: Maximum number of characters displayed from a string
#
# You can set them using `pd.set_option("display.max_rows", 1000)`, for example, to show 1000 rows at a time. You can find a lot more at https://pandas.pydata.org/pandas-docs/stable/generated/pandas.set_option.html
#
# ### Regular expressions reference
#
# I personally think http://www.regular-expressions.info/ is a wonderful wonderful reference (and tutorial), even if it's ugly! But here's a quick reference for you:
#
# * `\d` is a digit
# * `\d*` is zero or more digits
# * `\d+` is one or more digits
# * `.` matches anything for ONE character
# * `.*` is "give me anything forever"
# * `\s` is whitespace, a.k.a. spaces and tabs
# * `\w` is a word character, which includes capital and lowercase letters, numbers and hyphens.
# * You can put `*` after anything, so `\w*` would mean "as many word characters as you can find"
# * `\b` is a word boundary (you'll need the `r""` thing for this one)
# * `( )` is a "capture group" for saving something
# * `\1` is used when doing find/replace to say "put the first captured group here" (note, it's a dollar sign instead of a backslash in some editors)
# * `[ABCDE]` is a character class, which means "match one of these, I don't care which"
# * dollar sign means "end of the line"
# * caret ^ means "beginning of the line"
# * `\.` means "no really seriously I mean a period not just anything"
# * You can use `\` with anything else that would normally be a special character, too, not just periods. `(` or `[` or whatever.
#
# ### Cleaning up extracted columns
#
# Sometimes you get `\n` (newlines) or spaces or `\t` (tabs) or stuff at the beginning or the end of your column. `.str.strip()` will usually take care of that, just attach it after your `.str.extract()`
#
# After you extract something, it's still a string even though you look at it and know it's a number. Use `.astype(int)` to turn it into an integer (no decimal) or `.astype(float)` to turn it into a float (yes decimal)
#
# ### Writing regular expressions in general
#
# Even if I'm using regex in pandas or Python, I like to test them in my text editor with "Find." The highlighting really helps me see if I'm matching things! I also like to think "what stays the same?" when designing patterns, write those parts first, then fill in the blanks with what I want to capture.

# %% [markdown]
# ## Importing
#
# There might be more, I just wanted to put this up here for the `pd.set_option` part. It allows you to see a lot of content in a single column of pandas, which will be important for some parts below.

# %%
import re
import pandas as pd
pd.set_option('display.max_colwidth', 500)

# %% [markdown]
# # Part 1: Using `.str.extract` to pull data from columns in pandas
#
# ## 1.1 H&M
#
# Open up `hm.csv` from the `scraped` directory. I want **four new columns**:
#
# 1. `price_original`, the original price, one of the new price
# 2. `price_discounted`, the discounted price
# 3. `pct_discount`, the percent discount
# 4. `article_id`, the article id (from the url)
#
# Save as **hm_cleaned.csv**.
#
# **Note:** When you look at it, it... won't look right. I don't know why, pandas is weird. Look at the `price` column by itself using `df['price']` before you write your regex.
#
# **Tip:** Remember that `$` is a special regex symbol! You might need to escape it.
#
# **Tip:** When doing `.str.extract`, the whole match doesn't get captured, only what you put `()` around! Think about anchoring to different points of the string, or things in the string.
#
# **Tip:** Not all prices have cents!
#
# **Tip:** Your first instinct about how to compute the percent discount is probably wrong

# %%
contents = open("scraped/hm.csv").read()
contents[0:500]
# Out:
# 'name,price,url\nWashed Linen Duvet Cover Set,$59.99 $129,http://www.hm.com/us/product/13472?article=13472-N\nCandle in Glass Jar,$6.99 $17.99,http://www.hm.com/us/product/35079?article=35079-D\nGlittery Cushion Cover,$7.99 $17.99,http://www.hm.com/us/product/72462?article=72462-A\nTextured-weave Cushion Cover,$6.99 $12.99,http://www.hm.com/us/product/58926?article=58926-C\nStoneware Bowl,$17.99 $24.99,http://www.hm.com/us/product/74242?article=74242-A\nSlub-weave Cushion Cover,$3.99 $9.99,http://www.h'

# %%
df = pd.read_csv("scraped/hm.csv")

# %%
df.head()
# Out:
#                            name          price  \
# 0  Washed Linen Duvet Cover Set    $59.99 $129
# 1           Candle in Glass Jar   $6.99 $17.99
# 2        Glittery Cushion Cover   $7.99 $17.99
# 3  Textured-weave Cushion Cover   $6.99 $12.99
# 4                Stoneware Bowl  $17.99 $24.99
#
#                                                   url
# 0  http://www.hm.com/us/product/13472?article=13472-N
# 1  http://www.hm.com/us/product/35079?article=35079-D
# 2  http://www.hm.com/us/product/72462?article=72462-A
# 3  http://www.hm.com/us/product/58926?article=58926-C
# 4  http://www.hm.com/us/product/74242?article=74242-A

# %%
df.price.head()
# Out:
# 0      $59.99 $129
# 1     $6.99 $17.99
# 2     $7.99 $17.99
# 3     $6.99 $12.99
# 4    $17.99 $24.99
# Name: price, dtype: object

# %%
df['price_discounted'] = df.price.str.extract(r'(?:^[$])(\d\d?.\d?\d?)')

# %%
df['price_original'] = df.price.str.extract(r'(?:.[$])(\d\d?.\d?\d?)')

# %%
df['article_id'] = df.url.str.extract(r'(\d*-\w*$)')

# %%
#turning the series into floats
df['price_original'] = df['price_original'].astype('float')
df['price_discounted'] = df['price_discounted'].astype('float')

# %%
#counting the difference as a percentage and making a new series
decrease = df['price_original'] - df['price_discounted']
df['pct_discount'] = round (decrease/df['price_original']*100,1)

# %%
df.pct_discount.head()
# Out:
# 0    53.5
# 1    61.1
# 2    55.6
# 3    46.2
# 4    28.0
# Name: pct_discount, dtype: float64

# %%
df.head() #finaldf
# Out:
#                            name          price  \
# 0  Washed Linen Duvet Cover Set    $59.99 $129
# 1           Candle in Glass Jar   $6.99 $17.99
# 2        Glittery Cushion Cover   $7.99 $17.99
# 3  Textured-weave Cushion Cover   $6.99 $12.99
# 4                Stoneware Bowl  $17.99 $24.99
#
#                                                   url  price_discounted  \
# 0  http://www.hm.com/us/product/13472?article=13472-N             59.99
# 1  http://www.hm.com/us/product/35079?article=35079-D              6.99
# 2  http://www.hm.com/us/product/72462?article=72462-A              7.99
# 3  http://www.hm.com/us/product/58926?article=58926-C              6.99
# 4  http://www.hm.com/us/product/74242?article=74242-A             17.99
#
#    price_original article_id  pct_discount
# 0          129.00    13472-N          53.5
# 1           17.99    35079-D          61.1
# 2           17.99    72462-A          55.6
# 3           12.99    58926-C          46.2
# 4           24.99    74242-A          28.0

# %% [markdown]
# ## 1.2 Sci-Fi Authors
#
# Open up `sci-fi.csv` to clean. Get rid of the `\n` on the title and and give me six new columns:
#
# * `avg_rating`
# * `rating_count`
# * `total_score`
# * `score_votes`
# * `series` the series the book belongs to
# * `series_no` the book in the series that it is
#
# For series, I'm talking about e.g. `(The Hunger Games, #1)` is `series` "The Hunter Games" and `series_no` 1.
#
# Save as **sci-fi_cleaned.csv**.
#
# **Tip:** You don't need regex to clean the title - there's a special thing that removes whitespace from the beginning/end of strings
#
# **Tip:** Remember that `(` and `)` are special characters
#
# **BONUS:** When you make the `total_score` column, pay close attention to it. If you notice the problem, fix it.
#
# **BONUS:** You don't need these columns to be numbers, but life would be better if they were.

# %%
df = pd.read_csv("scraped/sci-fi.csv")
df.head(8)
# Out:
#                             full_rating  \
# 0     4.07 avg rating — 785,502 ratings
# 1   4.34 avg rating — 5,212,935 ratings
# 2     3.76 avg rating — 922,308 ratings
# 3     4.04 avg rating — 702,272 ratings
# 4      4.06 avg rating — 77,664 ratings
# 5   4.23 avg rating — 2,345,974 ratings
# 6   4.30 avg rating — 2,049,239 ratings
# 7   4.12 avg rating — 1,379,452 ratings
#
#                                                                                              full_score  \
# 0  \nscore: 28,539,\n              and\n292 people voted\n               \n              \n
# 1  \nscore: 27,566,\n              and\n282 people voted\n               \n              \n
# 2  \nscore: 20,049,\n              and\n205 people voted\n               \n              \n
# 3  \nscore: 17,684,\n              and\n185 people voted\n               \n              \n
# 4  \nscore: 16,070,\n              and\n165 people voted\n               \n              \n
# 5  \nscore: 12,935,\n              and\n134 people voted\n               \n              \n
# 6  \nscore: 12,261,\n              and\n128 people voted\n               \n              \n
# 7  \nscore: 11,238,\n              and\n117 people voted\n               \n              \n
#
#    rank                                                  title  \
# 0     1                                \nThe Handmaid's Tale\n
# 1     2            \nThe Hunger Games (The Hunger Games, #1)\n
# 2     3             \nFrankenstein, or The Modern Prometheus\n
# 3     4  \nA Wrinkle in Time (A Wrinkle in Time Quintet, #1)\n
# 4     5                          \nThe Left Hand of Darkness\n
# 5     6                          \nDivergent (Divergent, #1)\n
# 6     7               \nCatching Fire (The Hunger Games, #2)\n
# 7     8                          \nThe Giver (The Giver, #1)\n
#
#                                                       url
# 0                    /book/show/38447.The_Handmaid_s_Tale
# 1                     /book/show/2767052-the-hunger-games
# 2  /book/show/18490.Frankenstein_or_The_Modern_Prometheus
# 3                      /book/show/18131.A_Wrinkle_in_Time
# 4              /book/show/18423.The_Left_Hand_of_Darkness
# 5                           /book/show/13335037-divergent
# 6                        /book/show/6148028-catching-fire
# 7                               /book/show/3636.The_Giver

# %%
#getting rid of \n's
df.title.replace('\\n',' ', regex=True,inplace=True)
df.title.head(7)
# Out:
# 0                                   The Handmaid's Tale
# 1               The Hunger Games (The Hunger Games, #1)
# 2                Frankenstein, or The Modern Prometheus
# 3     A Wrinkle in Time (A Wrinkle in Time Quintet, #1)
# 4                             The Left Hand of Darkness
# 5                             Divergent (Divergent, #1)
# 6                  Catching Fire (The Hunger Games, #2)
# Name: title, dtype: object

# %%
df['avg_rating'] = df.full_rating.str.extract(r'(\d[.]\d\d?\savg rating)')

# %%
df['rating_count'] = df.full_rating.str.extract(r'(\d?\d?\d?,?\d?\d?\d?,?\d{2,3}\sratings)')

# %%
df['total_score'] = df.full_score.str.extract(r'(score:\s\d\d?,\d{3})')

# %%
df['score_votes'] = df.full_score.str.extract(r'(\d{2,3}\speople voted)')

# %%
df['series'] = df.title.str.extract(r'([(]\w*\s?\w*\s?\w*\s?\w*\s?\w*\s?\w*)')

# %%
#cleaning the series
df['series'].replace('\(',' ', regex=True,inplace=True) 
df['series'].fillna("No book", inplace = True)
df.series.head()
# Out:
# 0                       No book
# 1              The Hunger Games
# 2                       No book
# 3     A Wrinkle in Time Quintet
# 4                       No book
# Name: series, dtype: object

# %%
df['series_no'] = df.title.str.extract(r'(#\d.\d?)')

# %%
#cleaning the series
df['series_no'].replace('\)',' ', regex=True,inplace=True) 
df['series_no'].fillna("No book", inplace = True)
df.series_no.head()
# Out:
# 0    No book
# 1        #1
# 2    No book
# 3        #1
# 4    No book
# Name: series_no, dtype: object

# %%
df.to_csv("sci-fi_cleaned.csv", index=False)

# %% [markdown]
# ## 1.3 Where you're just doing one of my former students' projects
#
# Once upon a time my student Stefan did a project that involved some lawyer stuff. Most of the content was in PDFs, though! I converted them to text files and put them into the `pdfs` folder, and gave you code below to open up each of them and save their contents into a dataframe.
#
# What a nice dataframe! I want you to add the following columns to it:
#
# * `lawyer_app`, the applicant's lawyer (pro se means that they did it themselves, that's fine)
# * `lawyer_gov`, the government's lawyer
# * `judge`, the name of the judge
# * `access`, whether the clearance is granted or denied (although you might miss a few)
#
# Save as **court_cleaned.csv**.
#
# **Note:** You can look at the original PDFs, they're also included.
#
# **Note:** This uses a fun utility called `glob`, which is mostly fun because you use it as `glob.glob`. It's used to find files that match a certain filename pattern.
#
# **BONUS:** You'll be happy once you get the judge, but make sure it doesn't have any extra punctuation on it.
#
# **BONUS:** You can for some words using `.str.contains("blah")` and save it into new columns. Maybe `has_debt`, `has_bankruptcy`, etc.
#
# > It's okay if it isn't perfect. Converting PDF into data rarely is! Usually you get 90% of it done with computers, then send people to enter the other 10% by hand.

# %%
import glob
filenames = glob.glob("pdfs/*.txt")
contents = [open(filename, encoding="utf8").read() for filename in filenames]
cases_df = pd.DataFrame({'filename': filenames, 'content': contents})
pd.set_option("display.max_colwidth",1000)
pd.set_option("display.max_rows", 1000)

# %%
cases_df.head()
# Out:
#                    filename  \
# 0  pdfs/11-11916.h1.pdf.txt
# 1  pdfs/12-01601.a1.pdf.txt
# 2  pdfs/11-03073.h1.pdf.txt
# 3  pdfs/11-04909.h1.pdf.txt
# 4  pdfs/11-08313.h1.pdf.txt
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    content
# 0                                                                \n\nDEPARTMENT OF DEFENSE \n\nDEFENSE OFFICE OF HEARINGS AND APPEALS \n\n           \n             \n\n \n \nIn the matter of: \n \n \n \nApplicant for Security Clearance \n\nREDACTED \n\n \n\nISCR Case No. 11-11916 \n\nMENDEZ, Francisco, Administrative Judge: \n\n \nApplicant  did  not  mitigate  security  concerns  raised  by  his  exercise  of  foreign \ncitizenship,  including  the  possession  of  a  current  foreign  passport.  He  also  did  not \nmitigate  security  concerns  raised  by  his  substantial  ties  to  Russia  through  which  he \ncould be subjected to adverse foreign influence. Clearance is denied. \n \n\nHistory of the Case \n\nOn August 15, 2009, Applicant submitted a security clearance application (SCA). \nHe  voluntarily  disclosed  his  dual  U.S.-Russian  citizenship,  as  well  as  his  connections \nand property interest in Russia.  \n\n \nOn  April  17,  2014,  the  Department  of  Defense ...
# 1  KEYWORD: Guideline F\n\nDIGEST: Most of the document Applicant submitted on appeal were not previously submitted to\nthe Judge and the Board is prohibited from receiving or considering them.  Adverse decision\naffirmed.\n\nCASENO: 12-01601.a1\n\nDATE: 09/23/2016\n\nIn Re:\n\n-------\n\nApplicant for Security Clearance\n\nDATE: September 23, 2016\n\nISCR Case No. 12-01601\n\n)\n)\n)\n)\n)\n)\n)\n)\n\nAPPEAL BOARD DECISION\n\nAPPEARANCES\n\nFOR GOVERNMENT\n\nJames B. Norman, Esq., Chief Department Counsel\n\nFOR APPLICANT\n\nPro se\n\n
# The Department of Defense (DoD) declined to grant Applicant a security clearance.  On\nAugust 19, 2015, DoD issued a statement of reasons (SOR) advising Applicant of the basis for that\ndecision–security concerns raised under Guideline F (Financial Considerations) of Department of\nDefense Directive 5220.6 (Jan. 2, 1992, as amended) (Directive).  Applicant requested a decision\non the written record.  On June 27, 2016, after considering the record, Def...
# 2                                                                \n\n                        DEPARTMENT OF DEFENSE \n\n         DEFENSE OFFICE OF HEARINGS AND APPEALS \n\n \n \nIn the matter of: \n \n \n \nApplicant for Security Clearance \n\n \n\n \n\nISCR Case No. 11-03073 \n\n           \n             \n\n) \n) \n) \n) \n) \n \n \n\n \n \n\nAppearances \n\n______________ \n\n \nDecision \n\n______________ \n\n \n\n \n\n \n\n \n \n\nFor Government: Robert J. Kilmartin, Esq., Department Counsel \n\nFor Applicant: Mark S. Zaid, Esq. \n\nLOUGHRAN, Edward W., Administrative Judge: \n\n \nApplicant  mitigated  the  financial  considerations  security  concerns.  Eligibility  for \n\naccess to classified information is granted.  \n \n\nStatement of the Case \n\nOn October 28, 2014, the Department of Defense (DOD) issued a Statement of \nReasons  (SOR)  to  Applicant  detailing  security  concerns  under  Guideline  F,  financial \nconsiderations. The action was taken under Executive Order...
# 3                                                                \n\n            DEFENSE OFFICE OF HEARINGS AND APPEALS \n\n    DEPARTMENT OF DEFENSE \n\n          \n             \n\n \n\n \nIn the matter of: \n \n \n \nApplicant for Security Clearance \n\n \n \n\n \n\nISCR Case No. 11-04909 \n\n \n\nFor Government: Richard Stevens, Esq., Department Counsel \n\nFor Applicant: Pro se \n\n \n\n \nDUFFY, James F., Administrative Judge: \n\n \nApplicant  mitigated \n\nconsiderations). Clearance is granted. \n\nthe  security  concerns  under  Guideline  F  (financial \n\nStatement of the Case \n\nOn April 5, 2015, the Department of Defense (DOD) Consolidated Adjudications \nFacility  (CAF)  issued  Applicant  a  Statement  of  Reasons  (SOR)  detailing  security \nconcerns under Guideline F. DOD CAF took that action under Executive Order 10865, \nSafeguarding  Classified  Information  Within  Industry,  dated  February  20,  1960,  as \namended;  DOD  Directive  5220.6,  Defense  Industria...
# 4                                                              \n\n                           DEPARTMENT OF DEFENSE \n         DEFENSE OFFICE OF HEARINGS AND APPEALS \n\n \n\nISCR Case No. 11-08313 \n\n \nIn the matter of: \n \n \n \nApplicant for Security Clearance \n\n--------------- \n \n\n \n\n           \n             \n\n) \n) \n) \n) \n) \n \n\n \n \n\nAppearances \n\n______________ \n\n \nDecision \n\n______________ \n\nFor Government: Julie R. Mendez, Esquire, Department Counsel \n\nFor Applicant: Pro se \n\n \n \n\n \n\nMARSHALL, Jr., Arthur E., Administrative Judge: \n\n \n                                        Statement of the Case \n \nOn  April  4,  2014,  the  Department  of  Defense  (DOD)  issued  Applicant  a \nStatement  of  Reasons  (SOR)  detailing  security  concerns  under  Guideline  B  (Foreign \nInfluence) and Guideline E (Personal Conduct).1 In a response signed April 28, 2014, \nApplicant admitted all allegations and requested a hearing based on the writte...

# %% [markdown]
# Okay, now do the work and **make those new columns!**

# %%
cases_df['lawyer_app'] = cases_df.content.str.extract(r'(?:FOR APPLICANT|For Applicant:)(?:\s?\s?)(\w*..*\s*?)')

# %%
cases_df['lawyer_gov'] = cases_df.content.str.extract(r'(?:FOR GOVERNMENT|For Government:)(?:\s?\s?)(\w*..*\s*?)')

# %%
cases_df['judge'] = cases_df.content.str.extract(r'(\w*?,?.\w*?’?\w*?,?\s?w*?\.?,?\s?\w*?\s?\w*?\.?)(?:\s?)?(?:,?\s?Administrative Judge)')

# %%
cases_df['access'] = cases_df.content.str.extract(r" is (denied|granted)", re.IGNORECASE)

# %%
cases_df.head()
# Out:
#                    filename  \
# 0  pdfs/11-11916.h1.pdf.txt
# 1  pdfs/12-01601.a1.pdf.txt
# 2  pdfs/11-03073.h1.pdf.txt
# 3  pdfs/11-04909.h1.pdf.txt
# 4  pdfs/11-08313.h1.pdf.txt
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    content  \
# 0                                                                \n\nDEPARTMENT OF DEFENSE \n\nDEFENSE OFFICE OF HEARINGS AND APPEALS \n\n           \n             \n\n \n \nIn the matter of: \n \n \n \nApplicant for Security Clearance \n\nREDACTED \n\n \n\nISCR Case No. 11-11916 \n\nMENDEZ, Francisco, Administrative Judge: \n\n \nApplicant  did  not  mitigate  security  concerns  raised  by  his  exercise  of  foreign \ncitizenship,  including  the  possession  of  a  current  foreign  passport.  He  also  did  not \nmitigate  security  concerns  raised  by  his  substantial  ties  to  Russia  through  which  he \ncould be subjected to adverse foreign influence. Clearance is denied. \n \n\nHistory of the Case \n\nOn August 15, 2009, Applicant submitted a security clearance application (SCA). \nHe  voluntarily  disclosed  his  dual  U.S.-Russian  citizenship,  as  well  as  his  connections \nand property interest in Russia.  \n\n \nOn  April  17,  2014,  the  Department  of  Defense ...
# 1  KEYWORD: Guideline F\n\nDIGEST: Most of the document Applicant submitted on appeal were not previously submitted to\nthe Judge and the Board is prohibited from receiving or considering them.  Adverse decision\naffirmed.\n\nCASENO: 12-01601.a1\n\nDATE: 09/23/2016\n\nIn Re:\n\n-------\n\nApplicant for Security Clearance\n\nDATE: September 23, 2016\n\nISCR Case No. 12-01601\n\n)\n)\n)\n)\n)\n)\n)\n)\n\nAPPEAL BOARD DECISION\n\nAPPEARANCES\n\nFOR GOVERNMENT\n\nJames B. Norman, Esq., Chief Department Counsel\n\nFOR APPLICANT\n\nPro se\n\n
# The Department of Defense (DoD) declined to grant Applicant a security clearance.  On\nAugust 19, 2015, DoD issued a statement of reasons (SOR) advising Applicant of the basis for that\ndecision–security concerns raised under Guideline F (Financial Considerations) of Department of\nDefense Directive 5220.6 (Jan. 2, 1992, as amended) (Directive).  Applicant requested a decision\non the written record.  On June 27, 2016, after considering the record, Def...
# 2                                                                \n\n                        DEPARTMENT OF DEFENSE \n\n         DEFENSE OFFICE OF HEARINGS AND APPEALS \n\n \n \nIn the matter of: \n \n \n \nApplicant for Security Clearance \n\n \n\n \n\nISCR Case No. 11-03073 \n\n           \n             \n\n) \n) \n) \n) \n) \n \n \n\n \n \n\nAppearances \n\n______________ \n\n \nDecision \n\n______________ \n\n \n\n \n\n \n\n \n \n\nFor Government: Robert J. Kilmartin, Esq., Department Counsel \n\nFor Applicant: Mark S. Zaid, Esq. \n\nLOUGHRAN, Edward W., Administrative Judge: \n\n \nApplicant  mitigated  the  financial  considerations  security  concerns.  Eligibility  for \n\naccess to classified information is granted.  \n \n\nStatement of the Case \n\nOn October 28, 2014, the Department of Defense (DOD) issued a Statement of \nReasons  (SOR)  to  Applicant  detailing  security  concerns  under  Guideline  F,  financial \nconsiderations. The action was taken under Executive Order...
# 3                                                                \n\n            DEFENSE OFFICE OF HEARINGS AND APPEALS \n\n    DEPARTMENT OF DEFENSE \n\n          \n             \n\n \n\n \nIn the matter of: \n \n \n \nApplicant for Security Clearance \n\n \n \n\n \n\nISCR Case No. 11-04909 \n\n \n\nFor Government: Richard Stevens, Esq., Department Counsel \n\nFor Applicant: Pro se \n\n \n\n \nDUFFY, James F., Administrative Judge: \n\n \nApplicant  mitigated \n\nconsiderations). Clearance is granted. \n\nthe  security  concerns  under  Guideline  F  (financial \n\nStatement of the Case \n\nOn April 5, 2015, the Department of Defense (DOD) Consolidated Adjudications \nFacility  (CAF)  issued  Applicant  a  Statement  of  Reasons  (SOR)  detailing  security \nconcerns under Guideline F. DOD CAF took that action under Executive Order 10865, \nSafeguarding  Classified  Information  Within  Industry,  dated  February  20,  1960,  as \namended;  DOD  Directive  5220.6,  Defense  Industria...
# 4                                                              \n\n                           DEPARTMENT OF DEFENSE \n         DEFENSE OFFICE OF HEARINGS AND APPEALS \n\n \n\nISCR Case No. 11-08313 \n\n \nIn the matter of: \n \n \n \nApplicant for Security Clearance \n\n--------------- \n \n\n \n\n           \n             \n\n) \n) \n) \n) \n) \n \n\n \n \n\nAppearances \n\n______________ \n\n \nDecision \n\n______________ \n\nFor Government: Julie R. Mendez, Esquire, Department Counsel \n\nFor Applicant: Pro se \n\n \n \n\n \n\nMARSHALL, Jr., Arthur E., Administrative Judge: \n\n \n                                        Statement of the Case \n \nOn  April  4,  2014,  the  Department  of  Defense  (DOD)  issued  Applicant  a \nStatement  of  Reasons  (SOR)  detailing  security  concerns  under  Guideline  B  (Foreign \nInfluence) and Guideline E (Personal Conduct).1 In a response signed April 28, 2014, \nApplicant admitted all allegations and requested a hearing based on the writte...
#
#             lawyer_app                                       lawyer_gov  \
# 0              Pro se         David F. Hayes, Esq., Department Counsel
# 1               Pro se  James B. Norman, Esq., Chief Department Counsel
# 2  Mark S. Zaid, Esq.    Robert J. Kilmartin, Esq., Department Counsel
# 3              Pro se        Richard Stevens, Esq., Department Counsel
# 4              Pro se     Julie R. Mendez, Esquire, Department Counsel
#
#                       judge   access
# 0         MENDEZ, Francisco   denied
# 1                    DOHA)       NaN
# 2       LOUGHRAN, Edward W.  granted
# 3           DUFFY, James F.  granted
# 4  MARSHALL, Jr., Arthur E.   denied

# %% [markdown]
# # Reading books
#
# When you're doing text work, you're legally obligated work on Jane Austen's Pride and Prejudice (at least I *think* so). Let's do some naive analysis of it!
#
# ## Read in Jane Austen's Pride and Prejudice (without moving the file!)
#
# It's in the `data/` directory, and named `Austen_Pride.txt`.

# %%
P_and_P = open('data/Austen_Pride.txt').read()

# %% [markdown]
# ## Look at the first 500 or so characters of it

# %%
P_and_P[0:500]
# Out:
# ' Pride and Prejudice\nby Jane Austen\nChapter 1\nIt is a truth universally acknowledged, that a single man in possession of a good fortune, must be in want of a wife.\nHowever little known the feelings or views of such a man may be on his first entering a neighbourhood, this truth is so well fixed in the minds of the surrounding families, that he is considered the rightful property of some one or other of their daughters.\n"My dear Mr. Bennet," said his lady to him one day, "have you heard that Nethe'

# %% [markdown]
# ## Use a regular expression to find every "he" or "she" in the book. There should be about 3000 of them.
#
# **Tip:** Do you know about **word boundaries?** `\b` means "the beginning of end of a word."
#
# **Tip:** You might also want to use `re.IGNORECASE`. Maybe you'll need to google it?
#
# **Tip:** Do NOT use `re.compile`

# %%
found=re.findall(r"(\bhe\b|\bshe\b)",P_and_P,re.IGNORECASE)

# %%
len(found)
# Out:
# 3047

# %% [markdown]
# ## Use a regular expression to find those same "he" or "she"s, but also match *the word after it*
#
# The first four should be:
#
# * he is
# * he had
# * she told
# * he came

# %%
re.findall(r"\bs?he\s\w*",P_and_P,re.IGNORECASE)
# Out:
# ['he is',
#  'he had',
#  'she told',
#  'he came',
#  'he agreed',
#  'he is',
#  'he married',
#  'he may',
#  'he comes',
#  'she ought',
#  'he comes',
#  'he chooses',
#  'she is',
#  'She was',
#  'she was',
#  'she fancied',
#  'He had',
#  'he should',
#  'she had',
#  'he suddenly',
#  'She has',
#  'She is',
#  'she times',
#  'she will',
#  'she will',
#  'he continued',
#  'he wished',
#  'she began',
#  'she had',
#  'he spoke',
#  'he left',
#  'he would',
#  'he eluded',
#  'He was',
#  'he meant',
#  'He had',
#  'he had',
#  'he saw',
#  'he wore',
#  'She could',
#  'he could',
#  'she began',
#  'he might',
#  'he ought',
#  'he brought',
#  'he had',
#  'he was',
#  'he was',
#  'he was',
#  'he was',
#  'He was',
#  'he would',
#  'She is',
#  'he looked',
#  'he withdrew',
#  'She is',
#  'She told',
#  'she had',
#  'she had',
#  'he was',
#  'he had',
#  'He had',
#  'he ',
#  'he had',
#  'she entered',
#  'she looked',
#  'he actually',
#  'she was',
#  'he asked',
#  'he asked',
#  'he did',
#  'he seemed',
#  'she was',
#  'he inquired',
#  'she was',
#  'he danced',
#  'he had',
#  'he would',
#  'he had',
#  'He is',
#  'she was',
#  'She was',
#  'she added',
#  'he is',
#  'He walked',
#  'he walked',
#  'she admired',
#  'He is',
#  'He is',
#  'he possibly',
#  'He could',
#  'he certainly',
#  'she was',
#  'he was',
#  'he might',
#  'he was',
#  'he was',
#  'He did',
#  'he never',
#  'He was',
#  'he appeared',
#  'he had',
#  'he could',
#  'he had',
#  'he acknowledged',
#  'she smiled',
#  'he chose',
#  'he had',
#  'he had',
#  'he could',
#  'he was',
#  'he seemed',
#  'he danced',
#  'he admired',
#  'he _did_',
#  'he liked',
#  'he did',
#  'he thought',
#  'he is',
#  'he sat',
#  'she asked',
#  'he liked',
#  'he could',
#  'she said',
#  'he seemed',
#  'he never',
#  'he is',
#  'he had',
#  'he would',
#  'he is',
#  'he had',
#  'he had',
#  'he has',
#  'he had',
#  'she should',
#  'she continued',
#  'she would',
#  'he did',
#  'she had',
#  'she considered',
#  'She mentioned',
#  'she may',
#  'she feels',
#  'he may',
#  'she does',
#  'she does',
#  'he must',
#  'he does',
#  'he must',
#  'he must',
#  'he sees',
#  'she can',
#  'she is',
#  'she chooses',
#  'she is',
#  'she cannot',
#  'She has',
#  'She danced',
#  'she saw',
#  'she merely',
#  'she might',
#  'he had',
#  'she were',
#  'she had',
#  'she were',
#  'she was',
#  'he had',
#  'he looked',
#  'he made',
#  'she hardly',
#  'he began',
#  'he had',
#  'he was',
#  'he was',
#  'she was',
#  'he was',
#  'He began',
#  'she to',
#  'he does',
#  'he is',
#  'He has',
#  'she turned',
#  'she added',
#  'she could',
#  'she would',
#  'she was',
#  'she had',
#  'he continued',
#  'He paused',
#  'he was',
#  'he would',
#  'she instantly',
#  'he can',
#  'He is',
#  'he was',
#  'he would',
#  'she been',
#  'she will',
#  'He listened',
#  'she chose',
#  'She had',
#  'he was',
#  'she sees',
#  'she was',
#  'he say',
#  'She did',
#  'she was',
#  'she should',
#  'She will',
#  'she stays',
#  'she was',
#  'She declared',
#  'he goes',
#  'She was',
#  'she should',
#  'She was',
#  'she longed',
#  'She was',
#  'she was',
#  'she saw',
#  'she had',
#  'she must',
#  'she only',
#  'she had',
#  'she could',
#  'she could',
#  'she believed',
#  'she was',
#  'She had',
#  'he was',
#  'he found',
#  'she returned',
#  'she was',
#  'she had',
#  'She has',
#  'She really',
#  'She did',
#  'she be',
#  'she came',
#  'she mean',
#  'he replied',
#  'she is',
#  'she were',
#  'She was',
#  'she had',
#  'she should',
#  'she found',
#  'she declined',
#  'she would',
#  'she could',
#  'She is',
#  'He immediately',
#  'she could',
#  'he replied',
#  'she drew',
#  'she be',
#  'she will',
#  'She is',
#  'she was',
#  'she must',
#  'she must',
#  'she must',
#  'she could',
#  'she would',
#  'she was',
#  'he could',
#  'she very',
#  'she requested',
#  'she found',
#  'she had',
#  'She would',
#  'she expected',
#  'She is',
#  'she remains',
#  'she added',
#  'she is',
#  'she has',
#  'she had',
#  'he replied',
#  'He only',
#  'she called',
#  'He had',
#  'she would',
#  'she was',
#  'she is',
#  'She seems',
#  'she is',
#  'she was',
#  'he would',
#  'he did',
#  'he thought',
#  'he wrote',
#  'She longed',
#  'She performed',
#  'She had',
#  'She was',
#  'he did',
#  'she is',
#  'she added',
#  'he does',
#  'He made',
#  'He was',
#  'he does',
#  'He studies',
#  'He leaves',
#  'he did',
#  'he would',
#  'he has',
#  'she could',
#  'he was',
#  'he had',
#  'he applied',
#  'she seated',
#  'she turned',
#  'She hardly',
#  'she could',
#  'he should',
#  'he disliked',
#  'She could',
#  'she drew',
#  'She liked',
#  'She smiled',
#  'He repeated',
#  'he was',
#  'He really',
#  'he should',
#  'She often',
#  'she left',
#  'She then',
#  'she rambled',
#  'she was',
#  'she had',
#  'he had',
#  'He addressed',
#  'he was',
#  'He was',
#  'she should',
#  'she removed',
#  'she might',
#  'He then',
#  'She had',
#  'She assured',
#  'she was',
#  'She could',
#  'he merely',
#  'she had',
#  'she gave',
#  'She then',
#  'she turned',
#  'he may',
#  'he chooses',
#  'she replied',
#  'she got',
#  'she walked',
#  'she resolved',
#  'He was',
#  'He was',
#  'he declined',
#  'he could',
#  'he mean',
#  'She was',
#  'she could',
#  'he means',
#  'she allowed',
#  'he may',
#  'He owns',
#  'he replied',
#  'she had',
#  'He began',
#  'she was',
#  'she could',
#  'she much',
#  'she urged',
#  'she had',
#  'she was',
#  'she felt',
#  'She attracted',
#  'he liked',
#  'He wisely',
#  'he scarcely',
#  'he adhered',
#  'she even',
#  'he had',
#  'she often',
#  'he had',
#  'he thus',
#  'he pleases',
#  'she continued',
#  'he not',
#  'he does',
#  'he folded',
#  'He seems',
#  'he says',
#  'he is',
#  'he can',
#  'he thinks',
#  'He must',
#  'he mean',
#  'he would',
#  'he could',
#  'he be',
#  'she was',
#  'He was',
#  'He had',
#  'he complimented',
#  'he had',
#  'he did',
#  'He was',
#  'he begged',
#  'he was',
#  'He begged',
#  'she declared',
#  'he continued',
#  'he thought',
#  'he expected',
#  'he seemed',
#  'he protested',
#  'he had',
#  'he had',
#  'She had',
#  'he had',
#  'She had',
#  'he knew',
#  'he had',
#  'She had',
#  'she would',
#  'she made',
#  'She had',
#  'he could',
#  'he chose',
#  'she had',
#  'he had',
#  'she is',
#  'she live',
#  'she was',
#  'she any',
#  'She has',
#  'she is',
#  'she handsome',
#  'She is',
#  'She is',
#  'she could',
#  'she is',
#  'she been',
#  'he had',
#  'he listened',
#  'he started',
#  'he never',
#  'he chose',
#  'he opened',
#  'he had',
#  'she interrupted',
#  'he does',
#  'he offered',
#  'he acted',
#  'he would',
#  'he bore',
#  'he belonged',
#  'he had',
#  'he felt',
#  'he intended',
#  'he had',
#  'he meant',
#  'he found',
#  'he thought',
#  'she was',
#  'he had',
#  'she could',
#  'she could',
#  'she did',
#  'she must',
#  'she felt',
#  'she might',
#  'she could',
#  'he would',
#  'he had',
#  'he told',
#  'he was',
#  'he bowed',
#  'he could',
#  'he was',
#  'he had',
#  'He was',
#  'he said',
#  'she was',
#  'she should',
#  'she had',
#  'She received',
#  'he returned',
#  'he could',
#  'she could',
#  'he was',
#  'She had',
#  'she said',
#  'he walked',
#  'she had',
#  'she could',
#  'He protested',
#  'he had',
#  'she had',
#  'he supposed',
#  'he had',
#  'he was',
#  'he declared',
#  'he might',
#  'she had',
#  'she felt',
#  'he was',
#  'he found',
#  'she heard',
#  'she could',
#  'she had',
#  'he finally',
#  'he immediately',
#  'he certainly',
#  'he had',
#  'he had',
#  'he received',
#  'she was',
#  'she soon',
#  'she was',
#  'she chiefly',
#  'she could',
#  'She dared',
#  'He inquired',
#  'He is',
#  'He is',
#  'he or',
#  'he chooses',
#  'he is',
#  'he wishes',
#  'he must',
#  'he is',
#  'he had',
#  'he added',
#  'He was',
#  'He meant',
#  'he had',
#  'he hates',
#  'He deserves',
#  'he will',
#  'he expressed',
#  'He had',
#  'she continued',
#  'She could',
#  'she contented',
#  'he gave',
#  'He was',
#  'he felt',
#  'he should',
#  'he is',
#  'He has',
#  'He shook',
#  'she is',
#  'she was',
#  'she is',
#  'She is',
#  'He is',
#  'He cannot',
#  'he chooses',
#  'He does',
#  'He can',
#  'he thinks',
#  'he is',
#  'he is',
#  'he is',
#  'he had',
#  'he assured',
#  'he considered',
#  'she would',
#  'he asked',
#  'she replied',
#  'he certainly',
#  'she is',
#  'she and',
#  'she thought',
#  'he were',
#  'he has',
#  'she is',
#  'She has',
#  'she derives',
#  'he had',
#  'he said',
#  'he did',
#  'She could',
#  'he had',
#  'she had',
#  'she had',
#  'he did',
#  'he crowded',
#  'he could',
#  'she knew',
#  'he gave',
#  'he had',
#  'she had',
#  'he was',
#  'she had',
#  'she did',
#  'she could',
#  'he intended',
#  'he did',
#  'he would',
#  'she was',
#  'he entertained',
#  'She had',
#  'she could',
#  'She was',
#  'she was',
#  'she observed',
#  'he did',
#  'She had',
#  'he had',
#  'she could',
#  'he directly',
#  'She was',
#  'she could',
#  'she had',
#  'she was',
#  'She danced',
#  'he was',
#  'she returned',
#  'she found',
#  'she did',
#  'she accepted',
#  'He walked',
#  'she was',
#  'she was',
#  'she began',
#  'she made',
#  'He replied',
#  'she addressed',
#  'He smiled',
#  'she wished',
#  'He made',
#  'he asked',
#  'she and',
#  'She answered',
#  'he said',
#  'he may',
#  'He has',
#  'he is',
#  'he stopped',
#  'he turned',
#  'she replied',
#  'she said',
#  'She shook',
#  'he gravely',
#  'he coldly',
#  'She said',
#  'he was',
#  'he has',
#  'he cannot',
#  'he could',
#  'he was',
#  'he had',
#  'he could',
#  'he informed',
#  'She then',
#  'she was',
#  'he will',
#  'he has',
#  'he has',
#  'he never',
#  'he has',
#  'he say',
#  'He does',
#  'he has',
#  'he believes',
#  'he is',
#  'She then',
#  'she had',
#  'he had',
#  'he will',
#  'she ceased',
#  'he left',
#  'she eagerly',
#  'she could',
#  'she felt',
#  'he only',
#  'He answered',
#  'he was',
#  'she could',
#  'she turned',
#  'She saw',
#  'she felt',
#  'she plainly',
#  'she determined',
#  'she might',
#  'she considered',
#  'she vexed',
#  'she could',
#  'she might',
#  'she liked',
#  'She concluded',
#  'she could',
#  'he may',
#  'she could',
#  'She could',
#  'she dreaded',
#  'he was',
#  'she was',
#  'she saw',
#  'she had',
#  'she endeavour',
#  'she began',
#  'she watched',
#  'she might',
#  'She looked',
#  'she bore',
#  'She looked',
#  'She looked',
#  'He took',
#  'he must',
#  'He must',
#  'he cannot',
#  'he should',
#  'he owes',
#  'he concluded',
#  'he was',
#  'she think',
#  'he must',
#  'she could',
#  'She was',
#  'he could',
#  'she entreat',
#  'He assured',
#  'he was',
#  'he should',
#  'She owed',
#  'She was',
#  'he never',
#  'She felt',
#  'he would',
#  'he readily',
#  'he was',
#  'she should',
#  'she thought',
#  'he set',
#  'he supposed',
#  'he addressed',
#  'she can',
#  'she was',
#  'He can',
#  'she added',
#  'she sat',
#  'she could',
#  'he allowed',
#  'he continued',
#  'she condescended',
#  'she said',
#  'she cried',
#  'he first',
#  'she would',
#  'she thus',
#  'she would',
#  'he persisted',
#  'she entered',
#  'he trusted',
#  'he had',
#  'she would',
#  'she dared',
#  'she added',
#  'She is',
#  'she is',
#  'she would',
#  'she actually',
#  'she could',
#  'she is',
#  'She would',
#  'she entered',
#  'she vows',
#  'she will',
#  'he will',
#  'she entered',
#  'she had',
#  'she will',
#  'he will',
#  'She shall',
#  'she appeared',
#  'she wished',
#  'She talked',
#  'She endeavoured',
#  'He thought',
#  'he suffered',
#  'She was',
#  'she will',
#  'she likewise',
#  'she added',
#  'she comes',
#  'she can',
#  'She talked',
#  'she said',
#  'she could',
#  'he presently',
#  'He scarcely',
#  'he had',
#  'He was',
#  'he meant',
#  'He joined',
#  'he voluntarily',
#  'She highly',
#  'he particularly',
#  'she felt',
#  'she read',
#  'he and',
#  'he companion',
#  'she says',
#  'She then',
#  'she saw',
#  'she was',
#  'she is',
#  'he imagined',
#  'he will',
#  'he may',
#  'he comes',
#  'he should',
#  'He is',
#  'she inspires',
#  'he will',
#  'she finished',
#  'she is',
#  'she suspects',
#  'she means',
#  'She follows',
#  'he does',
#  'She is',
#  'she have',
#  'she would',
#  'she is',
#  'she may',
#  'he is',
#  'he took',
#  'he is',
#  'she is',
#  'he returns',
#  'she could',
#  'She represented',
#  'she felt',
#  'she was',
#  'she bewailed',
#  'she had',
#  'he had',
#  'she would',
#  'she would',
#  'he had',
#  'she did',
#  'He was',
#  'he was',
#  'he was',
#  'he walked',
#  'she dared',
#  'he earnestly',
#  'he was',
#  'he and',
#  'She had',
#  'he would',
#  'she had',
#  'she felt',
#  'she valued',
#  'She resolved',
#  'he returned',
#  'he was',
#  'he was',
#  'he was',
#  'he replied',
#  'he meditated',
#  'he thought',
#  'She rated',
#  'she thought',
#  'he might',
#  'she could',
#  'she could',
#  'she expected',
#  'she soon',
#  'he was',
#  'she wished',
#  'she had',
#  'she became',
#  'She had',
#  'she had',
#  'she would',
#  'she had',
#  'she had',
#  'she was',
#  'he unfolded',
#  'he must',
#  'he begged',
#  'he listened',
#  'she was',
#  'he left',
#  'she persisted',
#  'she was',
#  'she trusted',
#  'she herself',
#  'she principally',
#  'she could',
#  'she could',
#  'she could',
#  'he did',
#  'he pronounced',
#  'he said',
#  'he had',
#  'she said',
#  'she called',
#  'she was',
#  'she was',
#  'she grew',
#  'she might',
#  'he proceeded',
#  'he had',
#  'he hoped',
#  'he added',
#  'she wished',
#  'he trusted',
#  'she was',
#  'he should',
#  'She hated',
#  'she never',
#  'she was',
#  'she could',
#  'she feared',
#  'she felt',
#  'she was',
#  'she did',
#  'he did',
#  'she would',
#  'He was',
#  'he sometimes',
#  'she went',
#  'she was',
#  'she regarded',
#  'she concluded',
#  'she spoke',
#  'She complained',
#  'she went',
#  'he have',
#  'he left',
#  'she found',
#  'She wrote',
#  'she paid',
#  'he was',
#  'she doubted',
#  'she had',
#  'she had',
#  'she could',
#  'he might',
#  'he thought',
#  'she thought',
#  'he must',
#  'She could',
#  'he had',
#  'she could',
#  'She can',
#  'she gives',
#  'He will',
#  'He may',
#  'she soon',
#  'she is',
#  'she may',
#  'he is',
#  'he is',
#  'he were',
#  'she did',
#  'he saw',
#  'she had',
#  'he one',
#  'He is',
#  'he had',
#  'he had',
#  'He took',
#  'she had',
#  'she last',
#  'she continued',
#  'she could',
#  'she might',
#  'He made',
#  'she refused',
#  'she spoke',
#  'he was',
#  'he was',
#  'he offended',
#  'she may',
#  'she would',
#  'he really',
#  'he is',
#  'he would',
#  'he once',
#  'She will',
#  'She will',
#  'she felt',
#  'she did',
#  'she thought',
#  'she hoped',
#  'she might',
#  'she saw',
#  'she resolved',
#  'she left',
#  'she had',
#  'he belonged',
#  'she had',
#  ...]

# %% [markdown]
# ## Use capture groups to save the pronoun (he/she) as one match and the word as another
#
# The first five should look like
#
# ```
# [('he', 'is'),
#  ('he', 'had'),
#  ('she', 'told'),
#  ('he', 'came'),
#  ('he', 'agreed')]```

# %%
re.findall(r"(\bs?he)\s(\w*)",P_and_P,re.IGNORECASE)
# Out:
# [('he', 'is'),
#  ('he', 'had'),
#  ('she', 'told'),
#  ('he', 'came'),
#  ('he', 'agreed'),
#  ('he', 'is'),
#  ('he', 'married'),
#  ('he', 'may'),
#  ('he', 'comes'),
#  ('she', 'ought'),
#  ('he', 'comes'),
#  ('he', 'chooses'),
#  ('she', 'is'),
#  ('She', 'was'),
#  ('she', 'was'),
#  ('she', 'fancied'),
#  ('He', 'had'),
#  ('he', 'should'),
#  ('she', 'had'),
#  ('he', 'suddenly'),
#  ('She', 'has'),
#  ('She', 'is'),
#  ('she', 'times'),
#  ('she', 'will'),
#  ('she', 'will'),
#  ('he', 'continued'),
#  ('he', 'wished'),
#  ('she', 'began'),
#  ('she', 'had'),
#  ('he', 'spoke'),
#  ('he', 'left'),
#  ('he', 'would'),
#  ('he', 'eluded'),
#  ('He', 'was'),
#  ('he', 'meant'),
#  ('He', 'had'),
#  ('he', 'had'),
#  ('he', 'saw'),
#  ('he', 'wore'),
#  ('She', 'could'),
#  ('he', 'could'),
#  ('she', 'began'),
#  ('he', 'might'),
#  ('he', 'ought'),
#  ('he', 'brought'),
#  ('he', 'had'),
#  ('he', 'was'),
#  ('he', 'was'),
#  ('he', 'was'),
#  ('he', 'was'),
#  ('He', 'was'),
#  ('he', 'would'),
#  ('She', 'is'),
#  ('he', 'looked'),
#  ('he', 'withdrew'),
#  ('She', 'is'),
#  ('She', 'told'),
#  ('she', 'had'),
#  ('she', 'had'),
#  ('he', 'was'),
#  ('he', 'had'),
#  ('He', 'had'),
#  ('he', ''),
#  ('he', 'had'),
#  ('she', 'entered'),
#  ('she', 'looked'),
#  ('he', 'actually'),
#  ('she', 'was'),
#  ('he', 'asked'),
#  ('he', 'asked'),
#  ('he', 'did'),
#  ('he', 'seemed'),
#  ('she', 'was'),
#  ('he', 'inquired'),
#  ('she', 'was'),
#  ('he', 'danced'),
#  ('he', 'had'),
#  ('he', 'would'),
#  ('he', 'had'),
#  ('He', 'is'),
#  ('she', 'was'),
#  ('She', 'was'),
#  ('she', 'added'),
#  ('he', 'is'),
#  ('He', 'walked'),
#  ('he', 'walked'),
#  ('she', 'admired'),
#  ('He', 'is'),
#  ('He', 'is'),
#  ('he', 'possibly'),
#  ('He', 'could'),
#  ('he', 'certainly'),
#  ('she', 'was'),
#  ('he', 'was'),
#  ('he', 'might'),
#  ('he', 'was'),
#  ('he', 'was'),
#  ('He', 'did'),
#  ('he', 'never'),
#  ('He', 'was'),
#  ('he', 'appeared'),
#  ('he', 'had'),
#  ('he', 'could'),
#  ('he', 'had'),
#  ('he', 'acknowledged'),
#  ('she', 'smiled'),
#  ('he', 'chose'),
#  ('he', 'had'),
#  ('he', 'had'),
#  ('he', 'could'),
#  ('he', 'was'),
#  ('he', 'seemed'),
#  ('he', 'danced'),
#  ('he', 'admired'),
#  ('he', '_did_'),
#  ('he', 'liked'),
#  ('he', 'did'),
#  ('he', 'thought'),
#  ('he', 'is'),
#  ('he', 'sat'),
#  ('she', 'asked'),
#  ('he', 'liked'),
#  ('he', 'could'),
#  ('she', 'said'),
#  ('he', 'seemed'),
#  ('he', 'never'),
#  ('he', 'is'),
#  ('he', 'had'),
#  ('he', 'would'),
#  ('he', 'is'),
#  ('he', 'had'),
#  ('he', 'had'),
#  ('he', 'has'),
#  ('he', 'had'),
#  ('she', 'should'),
#  ('she', 'continued'),
#  ('she', 'would'),
#  ('he', 'did'),
#  ('she', 'had'),
#  ('she', 'considered'),
#  ('She', 'mentioned'),
#  ('she', 'may'),
#  ('she', 'feels'),
#  ('he', 'may'),
#  ('she', 'does'),
#  ('she', 'does'),
#  ('he', 'must'),
#  ('he', 'does'),
#  ('he', 'must'),
#  ('he', 'must'),
#  ('he', 'sees'),
#  ('she', 'can'),
#  ('she', 'is'),
#  ('she', 'chooses'),
#  ('she', 'is'),
#  ('she', 'cannot'),
#  ('She', 'has'),
#  ('She', 'danced'),
#  ('she', 'saw'),
#  ('she', 'merely'),
#  ('she', 'might'),
#  ('he', 'had'),
#  ('she', 'were'),
#  ('she', 'had'),
#  ('she', 'were'),
#  ('she', 'was'),
#  ('he', 'had'),
#  ('he', 'looked'),
#  ('he', 'made'),
#  ('she', 'hardly'),
#  ('he', 'began'),
#  ('he', 'had'),
#  ('he', 'was'),
#  ('he', 'was'),
#  ('she', 'was'),
#  ('he', 'was'),
#  ('He', 'began'),
#  ('she', 'to'),
#  ('he', 'does'),
#  ('he', 'is'),
#  ('He', 'has'),
#  ('she', 'turned'),
#  ('she', 'added'),
#  ('she', 'could'),
#  ('she', 'would'),
#  ('she', 'was'),
#  ('she', 'had'),
#  ('he', 'continued'),
#  ('He', 'paused'),
#  ('he', 'was'),
#  ('he', 'would'),
#  ('she', 'instantly'),
#  ('he', 'can'),
#  ('He', 'is'),
#  ('he', 'was'),
#  ('he', 'would'),
#  ('she', 'been'),
#  ('she', 'will'),
#  ('He', 'listened'),
#  ('she', 'chose'),
#  ('She', 'had'),
#  ('he', 'was'),
#  ('she', 'sees'),
#  ('she', 'was'),
#  ('he', 'say'),
#  ('She', 'did'),
#  ('she', 'was'),
#  ('she', 'should'),
#  ('She', 'will'),
#  ('she', 'stays'),
#  ('she', 'was'),
#  ('She', 'declared'),
#  ('he', 'goes'),
#  ('She', 'was'),
#  ('she', 'should'),
#  ('She', 'was'),
#  ('she', 'longed'),
#  ('She', 'was'),
#  ('she', 'was'),
#  ('she', 'saw'),
#  ('she', 'had'),
#  ('she', 'must'),
#  ('she', 'only'),
#  ('she', 'had'),
#  ('she', 'could'),
#  ('she', 'could'),
#  ('she', 'believed'),
#  ('she', 'was'),
#  ('She', 'had'),
#  ('he', 'was'),
#  ('he', 'found'),
#  ('she', 'returned'),
#  ('she', 'was'),
#  ('she', 'had'),
#  ('She', 'has'),
#  ('She', 'really'),
#  ('She', 'did'),
#  ('she', 'be'),
#  ('she', 'came'),
#  ('she', 'mean'),
#  ('he', 'replied'),
#  ('she', 'is'),
#  ('she', 'were'),
#  ('She', 'was'),
#  ('she', 'had'),
#  ('she', 'should'),
#  ('she', 'found'),
#  ('she', 'declined'),
#  ('she', 'would'),
#  ('she', 'could'),
#  ('She', 'is'),
#  ('He', 'immediately'),
#  ('she', 'could'),
#  ('he', 'replied'),
#  ('she', 'drew'),
#  ('she', 'be'),
#  ('she', 'will'),
#  ('She', 'is'),
#  ('she', 'was'),
#  ('she', 'must'),
#  ('she', 'must'),
#  ('she', 'must'),
#  ('she', 'could'),
#  ('she', 'would'),
#  ('she', 'was'),
#  ('he', 'could'),
#  ('she', 'very'),
#  ('she', 'requested'),
#  ('she', 'found'),
#  ('she', 'had'),
#  ('She', 'would'),
#  ('she', 'expected'),
#  ('She', 'is'),
#  ('she', 'remains'),
#  ('she', 'added'),
#  ('she', 'is'),
#  ('she', 'has'),
#  ('she', 'had'),
#  ('he', 'replied'),
#  ('He', 'only'),
#  ('she', 'called'),
#  ('He', 'had'),
#  ('she', 'would'),
#  ('she', 'was'),
#  ('she', 'is'),
#  ('She', 'seems'),
#  ('she', 'is'),
#  ('she', 'was'),
#  ('he', 'would'),
#  ('he', 'did'),
#  ('he', 'thought'),
#  ('he', 'wrote'),
#  ('She', 'longed'),
#  ('She', 'performed'),
#  ('She', 'had'),
#  ('She', 'was'),
#  ('he', 'did'),
#  ('she', 'is'),
#  ('she', 'added'),
#  ('he', 'does'),
#  ('He', 'made'),
#  ('He', 'was'),
#  ('he', 'does'),
#  ('He', 'studies'),
#  ('He', 'leaves'),
#  ('he', 'did'),
#  ('he', 'would'),
#  ('he', 'has'),
#  ('she', 'could'),
#  ('he', 'was'),
#  ('he', 'had'),
#  ('he', 'applied'),
#  ('she', 'seated'),
#  ('she', 'turned'),
#  ('She', 'hardly'),
#  ('she', 'could'),
#  ('he', 'should'),
#  ('he', 'disliked'),
#  ('She', 'could'),
#  ('she', 'drew'),
#  ('She', 'liked'),
#  ('She', 'smiled'),
#  ('He', 'repeated'),
#  ('he', 'was'),
#  ('He', 'really'),
#  ('he', 'should'),
#  ('She', 'often'),
#  ('she', 'left'),
#  ('She', 'then'),
#  ('she', 'rambled'),
#  ('she', 'was'),
#  ('she', 'had'),
#  ('he', 'had'),
#  ('He', 'addressed'),
#  ('he', 'was'),
#  ('He', 'was'),
#  ('she', 'should'),
#  ('she', 'removed'),
#  ('she', 'might'),
#  ('He', 'then'),
#  ('She', 'had'),
#  ('She', 'assured'),
#  ('she', 'was'),
#  ('She', 'could'),
#  ('he', 'merely'),
#  ('she', 'had'),
#  ('she', 'gave'),
#  ('She', 'then'),
#  ('she', 'turned'),
#  ('he', 'may'),
#  ('he', 'chooses'),
#  ('she', 'replied'),
#  ('she', 'got'),
#  ('she', 'walked'),
#  ('she', 'resolved'),
#  ('He', 'was'),
#  ('He', 'was'),
#  ('he', 'declined'),
#  ('he', 'could'),
#  ('he', 'mean'),
#  ('She', 'was'),
#  ('she', 'could'),
#  ('he', 'means'),
#  ('she', 'allowed'),
#  ('he', 'may'),
#  ('He', 'owns'),
#  ('he', 'replied'),
#  ('she', 'had'),
#  ('He', 'began'),
#  ('she', 'was'),
#  ('she', 'could'),
#  ('she', 'much'),
#  ('she', 'urged'),
#  ('she', 'had'),
#  ('she', 'was'),
#  ('she', 'felt'),
#  ('She', 'attracted'),
#  ('he', 'liked'),
#  ('He', 'wisely'),
#  ('he', 'scarcely'),
#  ('he', 'adhered'),
#  ('she', 'even'),
#  ('he', 'had'),
#  ('she', 'often'),
#  ('he', 'had'),
#  ('he', 'thus'),
#  ('he', 'pleases'),
#  ('she', 'continued'),
#  ('he', 'not'),
#  ('he', 'does'),
#  ('he', 'folded'),
#  ('He', 'seems'),
#  ('he', 'says'),
#  ('he', 'is'),
#  ('he', 'can'),
#  ('he', 'thinks'),
#  ('He', 'must'),
#  ('he', 'mean'),
#  ('he', 'would'),
#  ('he', 'could'),
#  ('he', 'be'),
#  ('she', 'was'),
#  ('He', 'was'),
#  ('He', 'had'),
#  ('he', 'complimented'),
#  ('he', 'had'),
#  ('he', 'did'),
#  ('He', 'was'),
#  ('he', 'begged'),
#  ('he', 'was'),
#  ('He', 'begged'),
#  ('she', 'declared'),
#  ('he', 'continued'),
#  ('he', 'thought'),
#  ('he', 'expected'),
#  ('he', 'seemed'),
#  ('he', 'protested'),
#  ('he', 'had'),
#  ('he', 'had'),
#  ('She', 'had'),
#  ('he', 'had'),
#  ('She', 'had'),
#  ('he', 'knew'),
#  ('he', 'had'),
#  ('She', 'had'),
#  ('she', 'would'),
#  ('she', 'made'),
#  ('She', 'had'),
#  ('he', 'could'),
#  ('he', 'chose'),
#  ('she', 'had'),
#  ('he', 'had'),
#  ('she', 'is'),
#  ('she', 'live'),
#  ('she', 'was'),
#  ('she', 'any'),
#  ('She', 'has'),
#  ('she', 'is'),
#  ('she', 'handsome'),
#  ('She', 'is'),
#  ('She', 'is'),
#  ('she', 'could'),
#  ('she', 'is'),
#  ('she', 'been'),
#  ('he', 'had'),
#  ('he', 'listened'),
#  ('he', 'started'),
#  ('he', 'never'),
#  ('he', 'chose'),
#  ('he', 'opened'),
#  ('he', 'had'),
#  ('she', 'interrupted'),
#  ('he', 'does'),
#  ('he', 'offered'),
#  ('he', 'acted'),
#  ('he', 'would'),
#  ('he', 'bore'),
#  ('he', 'belonged'),
#  ('he', 'had'),
#  ('he', 'felt'),
#  ('he', 'intended'),
#  ('he', 'had'),
#  ('he', 'meant'),
#  ('he', 'found'),
#  ('he', 'thought'),
#  ('she', 'was'),
#  ('he', 'had'),
#  ('she', 'could'),
#  ('she', 'could'),
#  ('she', 'did'),
#  ('she', 'must'),
#  ('she', 'felt'),
#  ('she', 'might'),
#  ('she', 'could'),
#  ('he', 'would'),
#  ('he', 'had'),
#  ('he', 'told'),
#  ('he', 'was'),
#  ('he', 'bowed'),
#  ('he', 'could'),
#  ('he', 'was'),
#  ('he', 'had'),
#  ('He', 'was'),
#  ('he', 'said'),
#  ('she', 'was'),
#  ('she', 'should'),
#  ('she', 'had'),
#  ('She', 'received'),
#  ('he', 'returned'),
#  ('he', 'could'),
#  ('she', 'could'),
#  ('he', 'was'),
#  ('She', 'had'),
#  ('she', 'said'),
#  ('he', 'walked'),
#  ('she', 'had'),
#  ('she', 'could'),
#  ('He', 'protested'),
#  ('he', 'had'),
#  ('she', 'had'),
#  ('he', 'supposed'),
#  ('he', 'had'),
#  ('he', 'was'),
#  ('he', 'declared'),
#  ('he', 'might'),
#  ('she', 'had'),
#  ('she', 'felt'),
#  ('he', 'was'),
#  ('he', 'found'),
#  ('she', 'heard'),
#  ('she', 'could'),
#  ('she', 'had'),
#  ('he', 'finally'),
#  ('he', 'immediately'),
#  ('he', 'certainly'),
#  ('he', 'had'),
#  ('he', 'had'),
#  ('he', 'received'),
#  ('she', 'was'),
#  ('she', 'soon'),
#  ('she', 'was'),
#  ('she', 'chiefly'),
#  ('she', 'could'),
#  ('She', 'dared'),
#  ('He', 'inquired'),
#  ('He', 'is'),
#  ('He', 'is'),
#  ('he', 'or'),
#  ('he', 'chooses'),
#  ('he', 'is'),
#  ('he', 'wishes'),
#  ('he', 'must'),
#  ('he', 'is'),
#  ('he', 'had'),
#  ('he', 'added'),
#  ('He', 'was'),
#  ('He', 'meant'),
#  ('he', 'had'),
#  ('he', 'hates'),
#  ('He', 'deserves'),
#  ('he', 'will'),
#  ('he', 'expressed'),
#  ('He', 'had'),
#  ('she', 'continued'),
#  ('She', 'could'),
#  ('she', 'contented'),
#  ('he', 'gave'),
#  ('He', 'was'),
#  ('he', 'felt'),
#  ('he', 'should'),
#  ('he', 'is'),
#  ('He', 'has'),
#  ('He', 'shook'),
#  ('she', 'is'),
#  ('she', 'was'),
#  ('she', 'is'),
#  ('She', 'is'),
#  ('He', 'is'),
#  ('He', 'cannot'),
#  ('he', 'chooses'),
#  ('He', 'does'),
#  ('He', 'can'),
#  ('he', 'thinks'),
#  ('he', 'is'),
#  ('he', 'is'),
#  ('he', 'is'),
#  ('he', 'had'),
#  ('he', 'assured'),
#  ('he', 'considered'),
#  ('she', 'would'),
#  ('he', 'asked'),
#  ('she', 'replied'),
#  ('he', 'certainly'),
#  ('she', 'is'),
#  ('she', 'and'),
#  ('she', 'thought'),
#  ('he', 'were'),
#  ('he', 'has'),
#  ('she', 'is'),
#  ('She', 'has'),
#  ('she', 'derives'),
#  ('he', 'had'),
#  ('he', 'said'),
#  ('he', 'did'),
#  ('She', 'could'),
#  ('he', 'had'),
#  ('she', 'had'),
#  ('she', 'had'),
#  ('he', 'did'),
#  ('he', 'crowded'),
#  ('he', 'could'),
#  ('she', 'knew'),
#  ('he', 'gave'),
#  ('he', 'had'),
#  ('she', 'had'),
#  ('he', 'was'),
#  ('she', 'had'),
#  ('she', 'did'),
#  ('she', 'could'),
#  ('he', 'intended'),
#  ('he', 'did'),
#  ('he', 'would'),
#  ('she', 'was'),
#  ('he', 'entertained'),
#  ('She', 'had'),
#  ('she', 'could'),
#  ('She', 'was'),
#  ('she', 'was'),
#  ('she', 'observed'),
#  ('he', 'did'),
#  ('She', 'had'),
#  ('he', 'had'),
#  ('she', 'could'),
#  ('he', 'directly'),
#  ('She', 'was'),
#  ('she', 'could'),
#  ('she', 'had'),
#  ('she', 'was'),
#  ('She', 'danced'),
#  ('he', 'was'),
#  ('she', 'returned'),
#  ('she', 'found'),
#  ('she', 'did'),
#  ('she', 'accepted'),
#  ('He', 'walked'),
#  ('she', 'was'),
#  ('she', 'was'),
#  ('she', 'began'),
#  ('she', 'made'),
#  ('He', 'replied'),
#  ('she', 'addressed'),
#  ('He', 'smiled'),
#  ('she', 'wished'),
#  ('He', 'made'),
#  ('he', 'asked'),
#  ('she', 'and'),
#  ('She', 'answered'),
#  ('he', 'said'),
#  ('he', 'may'),
#  ('He', 'has'),
#  ('he', 'is'),
#  ('he', 'stopped'),
#  ('he', 'turned'),
#  ('she', 'replied'),
#  ('she', 'said'),
#  ('She', 'shook'),
#  ('he', 'gravely'),
#  ('he', 'coldly'),
#  ('She', 'said'),
#  ('he', 'was'),
#  ('he', 'has'),
#  ('he', 'cannot'),
#  ('he', 'could'),
#  ('he', 'was'),
#  ('he', 'had'),
#  ('he', 'could'),
#  ('he', 'informed'),
#  ('She', 'then'),
#  ('she', 'was'),
#  ('he', 'will'),
#  ('he', 'has'),
#  ('he', 'has'),
#  ('he', 'never'),
#  ('he', 'has'),
#  ('he', 'say'),
#  ('He', 'does'),
#  ('he', 'has'),
#  ('he', 'believes'),
#  ('he', 'is'),
#  ('She', 'then'),
#  ('she', 'had'),
#  ('he', 'had'),
#  ('he', 'will'),
#  ('she', 'ceased'),
#  ('he', 'left'),
#  ('she', 'eagerly'),
#  ('she', 'could'),
#  ('she', 'felt'),
#  ('he', 'only'),
#  ('He', 'answered'),
#  ('he', 'was'),
#  ('she', 'could'),
#  ('she', 'turned'),
#  ('She', 'saw'),
#  ('she', 'felt'),
#  ('she', 'plainly'),
#  ('she', 'determined'),
#  ('she', 'might'),
#  ('she', 'considered'),
#  ('she', 'vexed'),
#  ('she', 'could'),
#  ('she', 'might'),
#  ('she', 'liked'),
#  ('She', 'concluded'),
#  ('she', 'could'),
#  ('he', 'may'),
#  ('she', 'could'),
#  ('She', 'could'),
#  ('she', 'dreaded'),
#  ('he', 'was'),
#  ('she', 'was'),
#  ('she', 'saw'),
#  ('she', 'had'),
#  ('she', 'endeavour'),
#  ('she', 'began'),
#  ('she', 'watched'),
#  ('she', 'might'),
#  ('She', 'looked'),
#  ('she', 'bore'),
#  ('She', 'looked'),
#  ('She', 'looked'),
#  ('He', 'took'),
#  ('he', 'must'),
#  ('He', 'must'),
#  ('he', 'cannot'),
#  ('he', 'should'),
#  ('he', 'owes'),
#  ('he', 'concluded'),
#  ('he', 'was'),
#  ('she', 'think'),
#  ('he', 'must'),
#  ('she', 'could'),
#  ('She', 'was'),
#  ('he', 'could'),
#  ('she', 'entreat'),
#  ('He', 'assured'),
#  ('he', 'was'),
#  ('he', 'should'),
#  ('She', 'owed'),
#  ('She', 'was'),
#  ('he', 'never'),
#  ('She', 'felt'),
#  ('he', 'would'),
#  ('he', 'readily'),
#  ('he', 'was'),
#  ('she', 'should'),
#  ('she', 'thought'),
#  ('he', 'set'),
#  ('he', 'supposed'),
#  ('he', 'addressed'),
#  ('she', 'can'),
#  ('she', 'was'),
#  ('He', 'can'),
#  ('she', 'added'),
#  ('she', 'sat'),
#  ('she', 'could'),
#  ('he', 'allowed'),
#  ('he', 'continued'),
#  ('she', 'condescended'),
#  ('she', 'said'),
#  ('she', 'cried'),
#  ('he', 'first'),
#  ('she', 'would'),
#  ('she', 'thus'),
#  ('she', 'would'),
#  ('he', 'persisted'),
#  ('she', 'entered'),
#  ('he', 'trusted'),
#  ('he', 'had'),
#  ('she', 'would'),
#  ('she', 'dared'),
#  ('she', 'added'),
#  ('She', 'is'),
#  ('she', 'is'),
#  ('she', 'would'),
#  ('she', 'actually'),
#  ('she', 'could'),
#  ('she', 'is'),
#  ('She', 'would'),
#  ('she', 'entered'),
#  ('she', 'vows'),
#  ('she', 'will'),
#  ('he', 'will'),
#  ('she', 'entered'),
#  ('she', 'had'),
#  ('she', 'will'),
#  ('he', 'will'),
#  ('She', 'shall'),
#  ('she', 'appeared'),
#  ('she', 'wished'),
#  ('She', 'talked'),
#  ('She', 'endeavoured'),
#  ('He', 'thought'),
#  ('he', 'suffered'),
#  ('She', 'was'),
#  ('she', 'will'),
#  ('she', 'likewise'),
#  ('she', 'added'),
#  ('she', 'comes'),
#  ('she', 'can'),
#  ('She', 'talked'),
#  ('she', 'said'),
#  ('she', 'could'),
#  ('he', 'presently'),
#  ('He', 'scarcely'),
#  ('he', 'had'),
#  ('He', 'was'),
#  ('he', 'meant'),
#  ('He', 'joined'),
#  ('he', 'voluntarily'),
#  ('She', 'highly'),
#  ('he', 'particularly'),
#  ('she', 'felt'),
#  ('she', 'read'),
#  ('he', 'and'),
#  ('he', 'companion'),
#  ('she', 'says'),
#  ('She', 'then'),
#  ('she', 'saw'),
#  ('she', 'was'),
#  ('she', 'is'),
#  ('he', 'imagined'),
#  ('he', 'will'),
#  ('he', 'may'),
#  ('he', 'comes'),
#  ('he', 'should'),
#  ('He', 'is'),
#  ('she', 'inspires'),
#  ('he', 'will'),
#  ('she', 'finished'),
#  ('she', 'is'),
#  ('she', 'suspects'),
#  ('she', 'means'),
#  ('She', 'follows'),
#  ('he', 'does'),
#  ('She', 'is'),
#  ('she', 'have'),
#  ('she', 'would'),
#  ('she', 'is'),
#  ('she', 'may'),
#  ('he', 'is'),
#  ('he', 'took'),
#  ('he', 'is'),
#  ('she', 'is'),
#  ('he', 'returns'),
#  ('she', 'could'),
#  ('She', 'represented'),
#  ('she', 'felt'),
#  ('she', 'was'),
#  ('she', 'bewailed'),
#  ('she', 'had'),
#  ('he', 'had'),
#  ('she', 'would'),
#  ('she', 'would'),
#  ('he', 'had'),
#  ('she', 'did'),
#  ('He', 'was'),
#  ('he', 'was'),
#  ('he', 'was'),
#  ('he', 'walked'),
#  ('she', 'dared'),
#  ('he', 'earnestly'),
#  ('he', 'was'),
#  ('he', 'and'),
#  ('She', 'had'),
#  ('he', 'would'),
#  ('she', 'had'),
#  ('she', 'felt'),
#  ('she', 'valued'),
#  ('She', 'resolved'),
#  ('he', 'returned'),
#  ('he', 'was'),
#  ('he', 'was'),
#  ('he', 'was'),
#  ('he', 'replied'),
#  ('he', 'meditated'),
#  ('he', 'thought'),
#  ('She', 'rated'),
#  ('she', 'thought'),
#  ('he', 'might'),
#  ('she', 'could'),
#  ('she', 'could'),
#  ('she', 'expected'),
#  ('she', 'soon'),
#  ('he', 'was'),
#  ('she', 'wished'),
#  ('she', 'had'),
#  ('she', 'became'),
#  ('She', 'had'),
#  ('she', 'had'),
#  ('she', 'would'),
#  ('she', 'had'),
#  ('she', 'had'),
#  ('she', 'was'),
#  ('he', 'unfolded'),
#  ('he', 'must'),
#  ('he', 'begged'),
#  ('he', 'listened'),
#  ('she', 'was'),
#  ('he', 'left'),
#  ('she', 'persisted'),
#  ('she', 'was'),
#  ('she', 'trusted'),
#  ('she', 'herself'),
#  ('she', 'principally'),
#  ('she', 'could'),
#  ('she', 'could'),
#  ('she', 'could'),
#  ('he', 'did'),
#  ('he', 'pronounced'),
#  ('he', 'said'),
#  ('he', 'had'),
#  ('she', 'said'),
#  ('she', 'called'),
#  ('she', 'was'),
#  ('she', 'was'),
#  ('she', 'grew'),
#  ('she', 'might'),
#  ('he', 'proceeded'),
#  ('he', 'had'),
#  ('he', 'hoped'),
#  ('he', 'added'),
#  ('she', 'wished'),
#  ('he', 'trusted'),
#  ('she', 'was'),
#  ('he', 'should'),
#  ('She', 'hated'),
#  ('she', 'never'),
#  ('she', 'was'),
#  ('she', 'could'),
#  ('she', 'feared'),
#  ('she', 'felt'),
#  ('she', 'was'),
#  ('she', 'did'),
#  ('he', 'did'),
#  ('she', 'would'),
#  ('He', 'was'),
#  ('he', 'sometimes'),
#  ('she', 'went'),
#  ('she', 'was'),
#  ('she', 'regarded'),
#  ('she', 'concluded'),
#  ('she', 'spoke'),
#  ('She', 'complained'),
#  ('she', 'went'),
#  ('he', 'have'),
#  ('he', 'left'),
#  ('she', 'found'),
#  ('She', 'wrote'),
#  ('she', 'paid'),
#  ('he', 'was'),
#  ('she', 'doubted'),
#  ('she', 'had'),
#  ('she', 'had'),
#  ('she', 'could'),
#  ('he', 'might'),
#  ('he', 'thought'),
#  ('she', 'thought'),
#  ('he', 'must'),
#  ('She', 'could'),
#  ('he', 'had'),
#  ('she', 'could'),
#  ('She', 'can'),
#  ('she', 'gives'),
#  ('He', 'will'),
#  ('He', 'may'),
#  ('she', 'soon'),
#  ('she', 'is'),
#  ('she', 'may'),
#  ('he', 'is'),
#  ('he', 'is'),
#  ('he', 'were'),
#  ('she', 'did'),
#  ('he', 'saw'),
#  ('she', 'had'),
#  ('he', 'one'),
#  ('He', 'is'),
#  ('he', 'had'),
#  ('he', 'had'),
#  ('He', 'took'),
#  ('she', 'had'),
#  ('she', 'last'),
#  ('she', 'continued'),
#  ('she', 'could'),
#  ('she', 'might'),
#  ('He', 'made'),
#  ('she', 'refused'),
#  ('she', 'spoke'),
#  ('he', 'was'),
#  ('he', 'was'),
#  ('he', 'offended'),
#  ('she', 'may'),
#  ('she', 'would'),
#  ('he', 'really'),
#  ('he', 'is'),
#  ('he', 'would'),
#  ('he', 'once'),
#  ('She', 'will'),
#  ('She', 'will'),
#  ('she', 'felt'),
#  ('she', 'did'),
#  ('she', 'thought'),
#  ('she', 'hoped'),
#  ('she', 'might'),
#  ('she', 'saw'),
#  ('she', 'resolved'),
#  ('she', 'left'),
#  ('she', 'had'),
#  ('he', 'belonged'),
#  ('she', 'had'),
#  ...]

# %%
pronoun = re.findall(r"(\bs?he)\s(?:\w*)",P_and_P,re.IGNORECASE)
verb = re.findall(r"(?:\bs?he)\s(\w*)",P_and_P,re.IGNORECASE)

# %% [markdown]
# ## Save those matches into a dataframe
#
# You can give the column names with `columns=['pronoun', 'verb']`

# %%
df_dict = {}
df_dict['pronoun'] = pronoun
df_dict['verb'] = verb

p_p_df = pd.DataFrame(df_dict)
p_p_df.head()
# Out:
#   pronoun    verb
# 0      he      is
# 1      he     had
# 2     she    told
# 3      he    came
# 4      he  agreed

# %% [markdown]
# ## How many times is each pronoun used?

# %%
p_p_df.pronoun.value_counts()
# Out:
# she    1325
# he     1056
# She     325
# He      234
# Name: pronoun, dtype: int64

# %% [markdown]
# ## Oh, wait, clean that up.
#
# Make it only 'he' and 'she' lowercase.
#
# It should be about 1600 'she' and 1300 'he'

# %%
p_p_df.pronoun.str.lower().value_counts()
# Out:
# she    1650
# he     1290
# Name: pronoun, dtype: int64

# %% [markdown]
# ## What are the top 20 most common verbs?

# %%
p_p_df.verb.value_counts().head(20)
# Out:
# was          372
# had          371
# could        172
# is           139
# would         94
# has           70
# did           67
# will          50
# might         46
# should        41
# felt          38
# must          37
# said          33
# saw           32
# added         31
# thought       31
# then          26
# replied       22
# looked        21
# continued     21
# Name: verb, dtype: int64

# %% [markdown]
# ## What are the top 20 most common verbs for 'he', and the top 20 most common for 'she'
#
# **Tip:** Don't use groupby, just filter. If you want to know how, though, you can also look at "value counts for different categories" on [this page](http://jonathansoma.com/lede/foundations-2017/classes/more-pandas/class-notes/)

# %%
p_p_df[p_p_df.pronoun.str.lower() == 'he'].verb.value_counts().head(20)
# Out:
# had        166
# was        160
# is          74
# has         49
# could       40
# would       35
# did         29
# should      26
# must        24
# will        24
# might       21
# replied     14
# said        13
# thought     13
# may         13
# came        13
# does        12
# never       12
# meant       11
# then        11
# Name: verb, dtype: int64

# %%
p_p_df[p_p_df.pronoun.str.lower() == 'she'].verb.value_counts().head(20)
# Out:
# was          212
# had          205
# could        132
# is            65
# would         59
# did           38
# felt          33
# saw           29
# will          26
# might         25
# added         23
# has           21
# said          20
# thought       18
# then          15
# should        15
# found         13
# must          13
# soon          12
# continued     11
# Name: verb, dtype: int64

# %% [markdown]
# ## Who cries more, men or women? Give me a percentage answer.
#
# **Tip:** It's `cried`, because of, you know, how books are written

# %%
round (p_p_df[p_p_df.verb == 'cried'].pronoun.value_counts(normalize=True) * 100,1)
# Out:
# she    91.7
# he      8.3
# Name: pronoun, dtype: float64

# %% [markdown]
# ## How much more common is 'he' than 'she' in J.R.R. Tolkein's Fellowship of the Ring? How does that compare to Pride and Prejudice?
#
# The book is in the same directory.

# %%
ring_text = open('data/Lord of the Rings - 01 - The Fellowship of the Ring - J. R. R. Tolkien - 1955.txt').read()

# %%
ring_text[0:100]
# Out:
# 'THE FELLOWSHIP OF THE RING\n\n\n\n\nBEING THE FIRST PART OF\n\nTHE LORD OF THE RINGS\n\nBY\n\nJ.R.R. TOLKIEN\n\n\n'

# %%
pronouns = re.findall(r"\bs?he\b", ring_text, re.IGNORECASE)
#pronouns

# %%
ring_df = pd.DataFrame(pronouns, columns=['pronoun'])
ring_df.pronoun.str.lower().value_counts()
# Out:
# he     3062
# she     159
# Name: pronoun, dtype: int64

# %%
p_p_df.pronoun.str.lower().value_counts() #PrideandPrejudice
# Out:
# she    1650
# he     1290
# Name: pronoun, dtype: int64
